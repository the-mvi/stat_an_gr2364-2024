# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил(-а) студент(-ка) гр. 2364 Валентов Егор Евгеньевич. Вариант №2

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Плотность нормального распределения:
#
# $p_{\overline{\xi}} \left(\overline{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overline{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overline{x}-\mu\right)\right)$
#
# Математическое ожидание и ковариационная матрица:
#
# $\mathbb{E}\left(A\overline{\xi}+\overline{b}\right) = A\cdot\mathbb{E}\overline{\xi}+\overline{b}$
#
# $\mathrm{Var}\left(A\overline{\xi}+\overline{b}\right)=A\cdot\mathrm{Var}\left(\overline{\xi}\right)\cdot A^{\intercal}$
#
# Стандартное нормальное распределение:
#
# $\mathbb{E} \begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix}$
#
# $\mathrm{Var} \begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix}1 & 0 \\ 0 & 1\end{pmatrix}$

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
#
# ### Задание 1
#
# Исходная функция распределения:
#
# $p_{\xi, \eta} (x, y) = C \cdot \exp \left(-\cfrac{1}{2} \left(7x^2+8xy+13y^2+6x-18y+12\right)\right)$
#
# Преобразуем полином таким образом, что бы чётко прослеживалось математическое ожидание и обратная ковариационная матрица:
#
# $7x^2+8xy+13y^2+6x-18y+12 = 7\left(x^2+\cfrac{8}{7}xy+\cfrac{16}{49}y^2\right)-7\cdot\cfrac{16}{49}y^2+13y^2+6x-18y+12 = 7\left(x+\cfrac{4}{7}y\right)^2+\cfrac{75}{7}y^2+6x-18y+12 =$
#
# $= 7\left(x+\cfrac{4}{7}y\right)^2+6\left(x+\cfrac{4}{7}y\right)-6\cdot\cfrac{4}{7}y-18y+\cfrac{75}{7}y^2+12 = 7\left(\left(x+\cfrac{4}{7}y\right)^2+\cfrac{6}{7}\left(x+\cfrac{4}{7}y\right)+\cfrac{9}{49}\right)-7\cdot\cfrac{9}{49}+\cfrac{75}{7}y^2+\cfrac{150}{7}y+12 =$
#
# $= 7\left(x+\cfrac{4}{7}y+\cfrac{3}{7}\right)^2+\cfrac{75}{7}y^2+\cfrac{150}{7}y+\cfrac{75}{7} = 7\left(x+\cfrac{4}{7}y+\cfrac{3}{7}\right)^2+\cfrac{75}{7}\left(y-1\right)^2$
#
# Запомним данное выражение (оно потребуется во втором задании):
#
# $\star = 7\left(x+\cfrac{4}{7}y+\cfrac{3}{7}\right)^2+\cfrac{75}{7}\left(y-1\right)^2$
#
# Продолжим:
#
# $7\left(x+\cfrac{4}{7}y+\cfrac{3}{7}\right)^2+\cfrac{75}{7}\left(y-1\right)^2 = 7\left(\left(x+1\right)+\cfrac{4}{7}\left(y-1\right)\right)^2+\cfrac{75}{7}\left(y-1\right)^2 = 7\left(x+1\right)^2+8\left(x+1\right)\left(y-1\right)+13\left(y-1\right)^2$
#
# Математическое ожидание:
#
# $\mathbb{E} \begin{pmatrix}\xi \\ \eta\end{pmatrix} = \begin{pmatrix}-1 \\ 1\end{pmatrix}$
#
# Ковариационная матрица:
#
# $\Sigma^{-1} = \begin{pmatrix}7 & 4 \\ 4 & 13\end{pmatrix}$
#
# $\Sigma = \cfrac{1}{75}\begin{pmatrix}13 & -4 \\ -4 & 7\end{pmatrix}$
#
# Дисперсии:
#
# $\mathbb{D} \xi = \cfrac{13}{75}$
#
# $\mathbb{D} \eta = \cfrac{7}{75}$
#
# Ковариация и корреляция:
#
# $\mathrm{cov} (\xi, \eta) = -\cfrac{4}{75}$
#
# $\rho (\xi, \eta) = \cfrac{\mathrm{cov} (\xi, \eta)}{\sqrt{\mathbb{D}\xi\mathbb{D}\eta}} = -\cfrac{4}{\sqrt{91}}$
#
# Константа:
#
# $\det \Sigma = \cfrac{1}{75}, n=2$
#
# $C = \cfrac{1}{\left(2\pi\right)^{n/2}\sqrt{\det\Sigma}} = \cfrac{1}{2\pi\sqrt{\cfrac{1}{75}}} = \cfrac{5\sqrt{3}}{2\pi}$
#
# $p_{\xi, \eta} (x, y) = \cfrac{5\sqrt{3}}{2\pi} \cdot \exp \left(-\cfrac{1}{2} \left(7x^2+8xy+13y^2+6x-18y+12\right)\right)$
#
# График:

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x = np.arange(-2, 0, 0.1)
y = np.arange(0, 2, 0.1)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 * 3 ** 0.5 / (2 * pi) * e ** (-0.5 * (7 * xgrid ** 2 + 8 * xgrid * ygrid + 13 * ygrid ** 2 + 6 * xgrid - 18 * ygrid + 12))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задание 2
#
# Воспользуемся выражением из первого задания:
#
# $\star = 7\left(x+\cfrac{4}{7}y+\cfrac{3}{7}\right)^2+\cfrac{75}{7}\left(y-1\right)^2 = \left(\sqrt{7}x+\cfrac{4\sqrt{7}}{7}y+\cfrac{3\sqrt{7}}{7}\right)^2+\left(\cfrac{5\sqrt{3}}{\sqrt{7}}y-\cfrac{5\sqrt{3}}{\sqrt{7}}\right)^2$
#
# Преобразование имеет вид:
#
# $\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = A\begin{pmatrix} \xi \\ \eta \end{pmatrix} + \overline{b}$
#
# Найдём матрицу $A$ и вектор $\overline{b}$:
#
# $A = \begin{pmatrix} \sqrt{7} & \cfrac{4\sqrt{7}}{7} \\ 0 & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}, \overline{b} = \begin{pmatrix} \cfrac{3\sqrt{7}}{7} \\ -\cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}$
#
# Подставим и посчитаем:
#
# $\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \sqrt{7} & \cfrac{4\sqrt{7}}{7} \\ 0 & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}\begin{pmatrix} \xi \\ \eta \end{pmatrix} + \begin{pmatrix} \cfrac{3\sqrt{7}}{7} \\ -\cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix} = \begin{pmatrix} \sqrt{7}\xi+\cfrac{4\sqrt{7}}{7}\eta+\cfrac{3\sqrt{7}}{7} \\ \cfrac{5\sqrt{3}}{\sqrt{7}}\eta-\cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}$
#
# Проверим полученное выражение:
#
# $\mathbb{E} \begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} \sqrt{7} & \cfrac{4\sqrt{7}}{7} \\ 0 & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}\begin{pmatrix} -1 \\ 1 \end{pmatrix} + \begin{pmatrix} \cfrac{3\sqrt{7}}{7} \\ -\cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix} = \begin{pmatrix} -\sqrt{7}+\cfrac{4\sqrt{7}}{7}+\cfrac{3\sqrt{7}}{7} \\ \cfrac{5\sqrt{3}}{\sqrt{7}}-\cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix} = \begin{pmatrix} 0 \\ 0 \end{pmatrix}$
#
# $\mathrm{Var} \begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = A\Sigma A^{\intercal} = \cfrac{1}{75}\begin{pmatrix} \sqrt{7} & \cfrac{4\sqrt{7}}{7} \\ 0 & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix}\begin{pmatrix}13 & -4 \\ -4 & 7\end{pmatrix}\begin{pmatrix} \sqrt{7} & 0 \\ \cfrac{4\sqrt{7}}{7} & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix} = \cfrac{1}{75}\begin{pmatrix}\cfrac{75}{\sqrt{7}} & 0 \\ -\cfrac{20\sqrt{3}}{\sqrt{7}} & 5\sqrt{21}\end{pmatrix}\begin{pmatrix} \sqrt{7} & 0 \\ \cfrac{4\sqrt{7}}{7} & \cfrac{5\sqrt{3}}{\sqrt{7}} \end{pmatrix} = \cfrac{1}{75}\begin{pmatrix}75 & 0 \\ 0 & 75\end{pmatrix} = \begin{pmatrix}1 & 0 \\ 0 & 1\end{pmatrix}$
#
# Математическое ожидание имеет нулевой вектор, а ковариационная матрица является единичной, следовательно, найденное нормальное распределение является стандартным.
#
# ### Задание 3
#
# Найдём собственные числа и собственные вектора у матрицы, обратной к ковариационной:
#
# $\Sigma^{-1} = \begin{pmatrix}7 & 4 \\ 4 & 13\end{pmatrix}$
#
# $\det \begin{pmatrix}7-\lambda & 4 \\ 4 & 13-\lambda\end{pmatrix} = 0$
#
# $\left(7-\lambda\right)\left(13-\lambda\right)-16 = \lambda^2-20\lambda+75 = 0$
#
# Собственные числа:
#
# $\lambda_1 = 5$
#
# $\lambda_2 = 15$
#
# Собственные вектора:
#
# $\begin{pmatrix}2 & 4 \\ 4 & 8\end{pmatrix}\begin{pmatrix}x_1 \\ x_2\end{pmatrix} = \begin{pmatrix}0 \\ 0\end{pmatrix}$
#
# $v_1 = \alpha\begin{pmatrix}2 \\ -1\end{pmatrix}$
#
# $\alpha = \cfrac{1}{\sqrt{2^2+\left(-1\right)^2}}=\cfrac{1}{\sqrt{5}} \Rightarrow v_1 = \cfrac{1}{\sqrt{5}}\begin{pmatrix}2 \\ -1\end{pmatrix}$
#
# $\begin{pmatrix}-8 & 4 \\ 4 & -2\end{pmatrix}\begin{pmatrix}x_1 \\ x_2\end{pmatrix} = \begin{pmatrix}0 \\ 0\end{pmatrix}$
#
# $v_2 = \cfrac{1}{\sqrt{5}}\begin{pmatrix}1 \\ 2\end{pmatrix}$
#
# Составим из собственных векторов матрицу $Q^{\intercal}$:
#
# $Q^{\intercal} = \cfrac{1}{\sqrt{5}}\begin{pmatrix}2 & 1 \\ -1 & 2\end{pmatrix}$
#
# $\mathbb{E} \begin{pmatrix}\xi_{id} \\ \eta_{id}\end{pmatrix} = \cfrac{1}{\sqrt{5}}\begin{pmatrix}2 & -1 \\ 1 & 2\end{pmatrix}\begin{pmatrix}-1 \\ 1\end{pmatrix} = \begin{pmatrix}\cfrac{-3}{\sqrt{5}} \\ \cfrac{1}{\sqrt{5}}\end{pmatrix}$
#
# Ортогональное преобразование:
#
# $\Sigma_{id} = Q \Sigma Q^{\intercal} = \cfrac{1}{75\cdot5}\begin{pmatrix}2 & -1 \\ 1 & 2\end{pmatrix}\begin{pmatrix}13 & -4 \\ -4 & 7\end{pmatrix}\begin{pmatrix}2 & 1 \\ -1 & 2\end{pmatrix} = \cfrac{1}{75\cdot5}\begin{pmatrix}30 & -15 \\ 5 & 10\end{pmatrix}\begin{pmatrix}2 & 1 \\ -1 & 2\end{pmatrix} = \cfrac{1}{75\cdot5}\begin{pmatrix}75 & 0 \\ 0 & 25\end{pmatrix} = \begin{pmatrix}1/5 & 0 \\ 0 & 1/15\end{pmatrix}$
#
# Распределение:
#
# $\Sigma^{-1}_{id} = \begin{pmatrix}5 & 0 \\ 0 & 15\end{pmatrix}$
#
# $p_{\xi, \eta} \left(x, y\right) = \cfrac{5\sqrt{3}}{2\pi} \cdot \exp \left(-\cfrac{1}{2}\left(5\left(x+\cfrac{3}{\sqrt{5}}\right)^2+15\left(y-\cfrac{1}{\sqrt{5}}\right)^2\right)\right)$
#
# График:

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x = np.arange(-3, 0, 0.1)
y = np.arange(-1, 2, 0.1)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 * 3 ** 0.5 / (2 * pi) * e ** (-0.5 * (5 * (xgrid + 3 / (5 ** 0.5)) ** 2 + 15 * (ygrid - 1 / (5 ** 0.5)) ** 2))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задание 4
#
# Применем преобразование:
#
# $\begin{pmatrix}-4\xi-2\eta \\ 2\xi-2\eta\end{pmatrix} = \begin{pmatrix}-4 & -2 \\ 2 & -2 \end{pmatrix}\begin{pmatrix}\xi \\ \eta\end{pmatrix}$
#
# Получим:
#
# $A = \begin{pmatrix}-4 & -2 \\ 2 & -2 \end{pmatrix}$
#
# Математическое ожидание:
#
# $\mathbb{E} \begin{pmatrix}-4\xi-2\eta \\ 2\xi-2\eta\end{pmatrix} = \begin{pmatrix}4-2 \\ -2-2\end{pmatrix} = \begin{pmatrix}2 \\ -4\end{pmatrix}$
#
# Ковариационная матрица:
#
# $\Sigma_1 = \mathrm{Var} \begin{pmatrix}-4\xi-2\eta \\ 2\xi-2\eta\end{pmatrix} = A\Sigma A^{\intercal} = \cfrac{1}{75}\begin{pmatrix}-4 & -2 \\ 2 & -2 \end{pmatrix}\begin{pmatrix}13 & -4 \\ -4 & 7\end{pmatrix}\begin{pmatrix}-4 & 2 \\ -2 & -2 \end{pmatrix} = \cfrac{1}{75}\begin{pmatrix}-44 & 2 \\ 34 & -22\end{pmatrix}\begin{pmatrix}-4 & 2 \\ -2 & -2 \end{pmatrix} = \cfrac{1}{75}\begin{pmatrix}172 & -92 \\ -92 & 112\end{pmatrix}$
#
# Дисперсии:
#
# $\mathbb{D} \left(-4\xi-2\eta\right) = \cfrac{172}{75}$
#
# $\mathbb{D} \left(2\xi-2\eta\right) = \cfrac{112}{75}$
#
# Ковариация и корреляция:
#
# $\mathrm{cov} (-4\xi-2\eta, 2\xi-2\eta) = -\cfrac{92}{75}$
#
# $\rho (-4\xi-2\eta, 2\xi-2\eta) = \cfrac{\mathrm{cov} (-4\xi-2\eta, 2\xi-2\eta)}{\sqrt{\mathbb{D}\left(-4\xi-2\eta\right)\mathbb{D}\left(2\xi-2\eta\right)}} = -\cfrac{92}{8\sqrt{301}}$
#
# Распределение:
#
# $\Sigma_1^{-1} = \cfrac{1}{144}\begin{pmatrix}112 & 92 \\ 92 & 172\end{pmatrix}$
#
# $\det \Sigma_1 = \cfrac{144}{75}$
#
# $p_{\xi_1, \eta_1} \left(x, y\right) = \cfrac{5\sqrt{3}}{24\pi} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{112\left(x-2\right)^2+184\left(x-2\right)\left(y+4\right)+172\left(y+4\right)^2}{144}\right)\right) = \cfrac{5\sqrt{3}}{24\pi} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{7}{9}\left(x-2\right)^2+\cfrac{23}{18}\left(x-2\right)\left(y+4\right)+\cfrac{43}{36}\left(y+4\right)^2\right)\right)$
#
# График:

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x = np.arange(-2, 6, 0.2)
y = np.arange(-8, 0, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 * 3 ** 0.5 / (24 * pi) * e ** (-0.5 * (112 * (xgrid - 2) ** 2 + 184 * (xgrid - 2) * (ygrid + 4) + 172 * (ygrid + 4) ** 2) / 144)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задание 5
#
# Распределение компоненты $\eta$:
#
# $p_\eta (y) = \cfrac{5\sqrt{3}}{\sqrt{7}\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{y-1}{\left(\cfrac{\sqrt{7}}{5\sqrt{3}}\right)}\right)^2\right) = \cfrac{5\sqrt{3}}{\sqrt{7}\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{75}{7}y^2-\cfrac{150}{7}y+\cfrac{75}{7}\right)\right)$
#
# Условное распределение:
#
# $p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} = \cfrac{\cfrac{5\sqrt{3}}{2\pi} \cdot \exp \left(-\cfrac{1}{2} \left(7x^2+8xy_0+13y_0^2+6x-18y_0+12\right)\right)}{\cfrac{5\sqrt{3}}{\sqrt{7}\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{75}{7}y_0^2-\cfrac{150}{7}y_0+\cfrac{75}{7}\right)\right)}$
#
# Сразу найдём дисперсию:
#
# $\cfrac{5\sqrt{3}\sqrt{7}\sqrt{2\pi}}{10\pi\sqrt{3}} = \cfrac{\sqrt{7}}{\sqrt{2\pi}}$
#
# $\mathbb{D} (\xi|\eta) = \cfrac{1}{7}$
#
# Продолжаем вычисления:
#
# $p_{\xi|\eta=y_0} (x) = \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(7x^2+8xy_0+\left(13-\cfrac{75}{7}\right)y_0^2+6x-\left(18-\cfrac{150}{7}\right)y_0+12-\cfrac{75}{7}\right)\right) =$
#
# $= \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(7x^2+8xy_0+\cfrac{16}{7}y_0^2+6x+\cfrac{24}{7}y_0+\cfrac{9}{7}\right)\right) = \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\cdot 7\left(x^2+\cfrac{8}{7}xy_0+\cfrac{16}{49}y_0^2+\cfrac{6}{7}x+\cfrac{24}{49}y_0+\cfrac{9}{49}\right)\right) =$
#
# $= \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\cdot 7\left(x^2+\left(\cfrac{8}{7}y_0+\cfrac{6}{7}\right)x+\cfrac{16}{49}y_0^2+\cfrac{24}{49}y_0+\cfrac{9}{49}\right)\right) = \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\cdot 7\left(x^2+2\left(\cfrac{4}{7}y_0+\cfrac{3}{7}\right)x+\left(\cfrac{4}{7}y_0+\cfrac{3}{7}\right)^2\right)\right) =$
#
# $= \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\cdot 7\left(x+\cfrac{4y_0+3}{7}\right)^2\right) = \cfrac{\sqrt{7}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\cdot \left(\cfrac{x+\cfrac{4y_0+3}{7}}{\left(\cfrac{1}{\sqrt{7}}\right)}\right)^2\right)$
#
# Математическое ожидание:
#
# $\mathbb{E} (\xi|\eta) = -\cfrac{4y_0+3}{7}$

# %% [markdown]
# ## Выводы
#
# Практическая работа позволила углубиться в изучение свойств двумерных случайных величин. Были получены знания не только по определению основных характеристик распределения, но и по выполнению преобразований, которые позволили нам перейти к стандартному нормальному вектору, а также к вектору с независимыми компонентами. Применение трехмерной визуализации распределений позволило наглядно продемонстрировать влияние этих преобразований на исходную величину. Полученный опыт поможет в дальнейшем анализе и моделировании сложных систем, включающих в себя взаимодействие нескольких случайных величин.
