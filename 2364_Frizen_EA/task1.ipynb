# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнила студента гр. 2364 Фризен Екатерина Александровна. Вариант №18

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Многомерное нормальное распределение:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ p_{\overrightarrow{\xi}} \left(\overrightarrow{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right) $
#
# Коэффициент ковариации:
#
# $ \rho (\xi, \eta) = \cfrac{\mathrm{cov} (\xi, \eta)}{\sqrt{\mathbb{D} \xi \cdot \mathbb{D} \eta}} $
#
# Афинное преобразование:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $
#
# Ортогональное преобразование:
#
# $ \Sigma_{id} = Q \Sigma Q^{\intercal} $
#
# Условное распределение:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} $
#
# Нормальное распределение:
#
# $ \xi \sim \mathcal{N}(a, \sigma^2) $
#
# $ p_\xi (x) = \cfrac{1}{\sigma\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{x-a}{\sigma}\right)^2\right) $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Номер 1
# Плотность двумерного нормального распределения имеет вид:
# $p_{{\xi},{\eta}}(x,y)=C\cdot \exp{(-\frac{1}{2}(3x^{2}-3xy + 7y^{2} +15x +5y +25))}$
#
# Задание 1.
# Вычислить вектор математических ожиданий и ковариационные характеристиики данного случайного вектора. Построить график плотности распределния $p_{{\xi},{\eta}}$
#
# Исходное выражение преобразуем(выражение из скобок):
# $3(x^2-xy+\frac{1}{4}y^2)+\frac{25}{4}y^2 + 15x + 5y+25 = 3(x-\frac{1}{2}y)^2 + \frac{25y^2}{4} = 15(x-\frac{1}{2}y) + \frac{25}{4}y + 25 = 3((x-\frac{1}{2}y)^2 + 5(x-\frac{1}{2}y) + \frac{25}{4}) + \frac{25y^2}{4} + \frac{25}{2}y + \frac{25}{4} = 3((x-\frac{1}{2}y) + \frac{5}{2})^2 + \frac{25}{4}(y+1)^2 = 3((x+3) - \frac{1}{2}(y+1))^2 + \frac{25}{4}(y+1)^2 = 3(x+3)^2 - 3(x+3)(y+1) + 7(y+1)^2$
#
# Вектор математических ожиданий:
#
# $ \mathbb{E} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} = \begin{pmatrix}
# -3\\
# -1
# \end{pmatrix} $
#
# Обратная ковариационная матрица:
#
# $ \Sigma^{-1} = \begin{pmatrix}
# 3 & \ -3/2\\
# -3/2 & 7
# \end{pmatrix} $
#
# Обратим ковариационную матрицу:
#
# $ \Sigma = \cfrac{4}{75}\begin{pmatrix}
# 7 & \ 3/2\\
# 3/2 & 3
# \end{pmatrix} $
#
# Константа С:
#
# $C = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} = \cfrac{5\sqrt{3}}{4\pi}$
#
# Итог:
#
# $ p_{\xi, \eta}  (x, y) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2-3xy+7y^2+15x+5y+25\right)\right) $

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(-5, -1, 0.1) 
y = np.arange(-3, 1, 0.1) 
xgrid, ygrid = np.meshgrid(x, y) 
zgrid = 5 * 3 ** 0.5 / (4 * 3.14) * 2.72 ** (-0.5 * (3 * xgrid ** 2 - 3 * xgrid * ygrid + 7 * ygrid ** 2  + 15* xgrid + 5 * ygrid + 25))
fig = plt.figure() 
ax = plt.axes(projection="3d") 
ax.plot_surface(xgrid, ygrid, zgrid) 
plt.show()

# %% [markdown]
# ## Номер 2
# Плотность двумерного нормального распределения имеет вид:
# $p_{{\xi},{\eta}}(x,y)=C\cdot \exp{(-\frac{1}{2}(3x^{2}-3xy + 7y^{2} +15x +5y +25))}$
#
# Задание 2.
# Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# $\star = (\sqrt{3}x - \frac{\sqrt{3}}{2}y + \frac{5\sqrt{3}}{2})^2 + (\frac{5}{2}y + \frac{5}{2})^2$
#
# $ \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = \begin{pmatrix}
# \sqrt{3} & \cfrac{-\sqrt{3}}{2} \\
# 0 & \cfrac{5}{2}
# \end{pmatrix} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} + \begin{pmatrix}
# \cfrac{5\sqrt{3}}{2} \\
# \cfrac{5}{2}
# \end{pmatrix} $

# %% [markdown]
# ## Номер 3
# Плотность двумерного нормального распределения имеет вид:
# $p_{{\xi},{\eta}}(x,y)=C\cdot \exp{(-\frac{1}{2}(3x^{2}-3xy + 7y^{2} +15x +5y +25))}$
#
# Задание 3.
# Найти ортогональное преоразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределния.
#
# Собственные числа и вектора:
#
# $ \det \begin{pmatrix}
# 3 - \lambda & \ -3/2\\
# -3/2 & 7 - \lambda
# \end{pmatrix} = \left(3 - \lambda\right)\left(7 - \lambda\right) - \cfrac{9}{4} = \lambda^2 - 10\lambda + \cfrac{75}{4} = 0 $
#
# $4\lambda^2-40\lambda+75=0$
#
# $4\lambda^2-10\lambda-30\lambda+75=0$
#
# $2\lambda(2\lambda-5) - 15(2\lambda - 5)=0$
#
# $(2\lambda-5)(2\lambda-15)=0$
#
# $\lambda_1 = \frac{5}{2}$
#
# $\lambda_2 = \frac{15}{2}$
#
# $ \lambda_1 = \cfrac{5}{2} \Rightarrow \begin{pmatrix}
# 1/2 & \ -3/2\\
# -3/2 & 9/2
# \end{pmatrix} \overrightarrow{v_1} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# $ \overrightarrow{v_1} = \alpha \begin{pmatrix}3\\
# 1
# \end{pmatrix} $
#
# $\alpha= \frac{1}{\sqrt{3^2+1^2}}=\frac{1}{\sqrt{10}}$
#
# Аналогично для $\lambda_2$:
#
# $ \lambda_2 = \cfrac{15}{2} \Rightarrow \begin{pmatrix}
# -9/2 & \ -3/2\\
# -3/2 & -1/2
# \end{pmatrix} \overrightarrow{v_2} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# $ \overrightarrow{v_2} = \alpha \begin{pmatrix}-1\\
# 3
# \end{pmatrix} $
#
# $Q^T = \frac{1}{\sqrt{10}} \begin{pmatrix}
# 3 & -1\\
# 1 & 3
# \end{pmatrix} \Rightarrow Q = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 3 & 1\\
# -1 & 3
# \end{pmatrix} $
#
# $ \Sigma_{id} = Q \Sigma Q^{T} = \cfrac{1}{\sqrt{10}} \cdot \cfrac{4}{75} \cdot \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 3 & 1\\
# -1 & 3
# \end{pmatrix} \begin{pmatrix}
# 7 & \ 3/2\\
# 3/2 & 3
# \end{pmatrix} \begin{pmatrix}
# 3 & -1\\
# 1 & 3
# \end{pmatrix} =  \begin{pmatrix}
# 2/5 & \ 0\\
# 0 & 2/15
# \end{pmatrix} $
#
# $\Sigma_{id}^{-1} = \begin{pmatrix}
# 5/2 & 0\\
# 0 & 15/2
# \end{pmatrix}$
#
# $ p_{\xi_1, \eta_1}  (x, y) = \cfrac{1}{2\pi \sqrt{\cfrac{4}{75}}} \cdot \exp \left(-\cfrac{1}{2}\left(x, y\right)\begin{pmatrix}
# 5/2 & 0\\
# 0 & 15/2
# \end{pmatrix}\begin{pmatrix}
# x\\
# y
# \end{pmatrix}\right) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{5}{2}x^2 + \cfrac{15}{2}y^2\right)\right) $

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(-2, 2, 0.1) 
y = np.arange(-2, 2, 0.1) 
xgrid, ygrid = np.meshgrid(x, y) 
zgrid = 5 * 3 ** 0.5 / (4 * 3.14) * 2.72 ** (-0.5 * (5/2 * xgrid ** 2 + 15/2 * ygrid ** 2 ))
fig = plt.figure() 
ax = plt.axes(projection="3d") 
ax.plot_surface(xgrid, ygrid, zgrid) 
plt.show()

# %% [markdown]
# ## Номер 4
# Плотность двумерного нормального распределения имеет вид:
# $p_{{\xi},{\eta}}(x,y)=C\cdot \exp{(-\frac{1}{2}(3x^{2}-3xy + 7y^{2} +15x +5y +25))}$
#
# Задание 4.
# Вычислить характеристики совместного распределения случайного вектора $(3\xi - 5\eta, 4\xi + \eta)^T$ и записать его плотность. Построить график плотности полученного распределения.
#
#
# $ \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = \begin{pmatrix}
# 3\xi -5\eta\\
# 4\xi + \eta
# \end{pmatrix} = \begin{pmatrix}
# 3 & -5\\
# 4 & 1
# \end{pmatrix} \cdot \begin{pmatrix}
# \xi \\
# \eta
# \end{pmatrix}$
#
#
# $ B = \begin{pmatrix}
# 3 & -5\\
# 4 & 1
# \end{pmatrix} $
#
#
# $ \mathbb{E} \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = \begin{pmatrix}
# -4\\
# -13
# \end{pmatrix} $
#
# $ \Sigma^{'} = B \Sigma B^{T} = \cfrac{4}{75} \begin{pmatrix}
# 3 & -5\\
# 4 & 1
# \end{pmatrix} \begin{pmatrix}
# 7 & \ 3/2\\
# 3/2 & 3
# \end{pmatrix} \begin{pmatrix}
# 3 & 4\\
# -5 & 1
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# 93 & \ 43.5\\
# 43.5 & 127
# \end{pmatrix} $
#
# Совместные характеристики:
#
# $\mathbb{D}_{\xi_2} = \cfrac{372}{75}, \mathbb{D}_{\eta_2} = \cfrac{508}{75}, cov(\xi_2, \eta_2) = \cfrac{174}{75}, \rho (\xi_2, \eta_2)=0,4$
#
# $ p_{\xi_2, \eta_2}  (x, y) = \cfrac{1}{2\pi \sqrt{\cfrac{2116}{75}}} \cdot \exp \left(-\cfrac{1}{2} \cdot \cfrac{1}{1058} \left(x+4, y+13\right)\begin{pmatrix}
# 254 & -87\\
# -87 & 186
# \end{pmatrix}\begin{pmatrix}
# x+4\\
# y+13
# \end{pmatrix}\right) = \cfrac{5\sqrt{3}}{4\pi \sqrt{529}} \cdot \exp \left(-\cfrac{1}{2} \cdot \cfrac{1}{1058} \left(254(x+4)^2 -174(x+4)(y+13) + 186(y+13)^2\right)\right) $

# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = np.arange(-10, 2, 0.1) 
y = np.arange(-19, -7, 0.1) 
xgrid, ygrid = np.meshgrid(x, y) 
zgrid = 5 * 3 ** 0.5 / (4 * 3.14 * 529 ** 0.5) * 2.72 ** (-0.5 * 1/1058 *(254*(xgrid+4)**2  - 174*(xgrid+4)*(ygrid+13) + 186*(ygrid + 13)**2 ))
fig = plt.figure() 
ax = plt.axes(projection="3d") 
ax.plot_surface(xgrid, ygrid, zgrid) 
plt.show()

# %% [markdown]
# ## Номер 5
# Плотность двумерного нормального распределения имеет вид:
# $p_{{\xi},{\eta}}(x,y)=C\cdot \exp{(-\frac{1}{2}(3x^{2}-3xy + 7y^{2} +15x +5y +25))}$
#
# Задание 5.
# Найти условное распределение $\xi$ при условии $\eta$. Вычислить $ \mathbb{E} \left(\xi|\eta\right) $ и $ \mathbb{D} \left(\xi|\eta\right) $.
#
# $ \mathbb{E} \eta = -1$
#
# $ \mathbb{D} \eta = \cfrac{4}{25} $
#
# $ p_\eta (y) = \cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{y+1}{\cfrac{2}{5}}\right)^2\right) = \cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{25}{4}y^2+\cfrac{25}{2}y+\cfrac{25}{4}\right)\right) $
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{\cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^{2}-3xy_0 + 7y_0^{2} +15x +5y_0 +25\right)\right)}{\cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{25}{4}y_0^2+\cfrac{25}{2}y_0+\cfrac{25}{4}\right)\right)} = \frac{\sqrt{3}}{\sqrt{2\pi}}\exp(-\frac{1}{2}\cdot3(x^2 - (y_0 - 5)x + \frac{1}{4}y_0 - \frac{5}{2}y_0 + \frac{25}{4})) = \frac{\sqrt{3}}{\sqrt{2\pi}}\exp (-\frac{1}{2}\cdot (\frac{x-(y_0 - 5)}{1/3})^2) $
#
#
# $ \mathbb{D} \xi|\eta = \cfrac{1}{3} $
#
# $ \mathbb{E} \xi|\eta = y_0 - 5$

# %% [markdown]
# ## Выводы
# Исследованы свойства двумерного случайного вектора, получены навыки преобразования нормального вектора в стандартный и в вектор с независимыми компоннтами.
