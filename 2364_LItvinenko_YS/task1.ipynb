# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2364 Литвиненко Яков Сергеевич. Вариант №10

# %% [markdown]
# ## Цель работы
#
# сследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Формула нормального распределения:
#
# $ p(x)=\cfrac{1}{\sigma\sqrt{2\pi}} \cdot\exp\left(-\frac{1}{2} \left(\frac{(x-m)^2}{(\sigma)^2}\right)\right)$
#
# Афинное преобразование:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $
#
# Формула для нахождения коэфицента кореляции:
#
# $\rho (\xi, \eta) = \cfrac{\mathrm{cov} (\xi, \eta)}{\sqrt{\mathbb{D} \xi \cdot \mathbb{D} \eta}}$
#
# Формула для ортагонального преобразования:
#
# $\Sigma_{id} = Q \cdot \Sigma \cdot Q^{T} \rightarrow \Sigma_{id}$
#
# Формула для нахождения условного распределения:
#
# $\rho_{\xi|\eta}(x)= \frac{\rho_{\xi,\eta}(x,y)}{\rho_\eta(y)}$

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
#
# ### Задача №1.
#
# Плотность двумерного нормального распределения имеет вид:
#
# $ p_{\xi, \eta}  (x, y) = C \cdot \exp \left(-\cfrac{1}{2}\left(2x^2+4xy+5y^2-8x-2y+11\right)\right) $
#
# Необходимо вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $ p_{\xi, \eta} $ .
#
# $ С= \frac{1}{(2\pi)^2 \cdot \sqrt{det\sum_{}^{}}}   $
#
# Для того чтобы найти коэфицент C необходимо преобразоать исходное выражение:
# $2x^2+4xy+5y^2-8x-2y+11=2x^2+4xy+5y^2-8x-2y+11-8y+8y=2x^2+4xy-8x+2y^2-8y+8+3y^2+6y+3=$
# $=2x^2+4xy-8x+2y^2-8y+8+3(y^2+2y+1)=2x^2+4xy-8x+2y^2-8y+8+3(y+1)^2=$
# $=2x^2+4xy-8x+2(y-2)^2+3(y+1)^2=2(x^2+2xy-4x+(y-2)^2)+3(y+1)^2=$
# $=2(x^2+2x(y-2)+(y-2)^2)+3(y+1)^2=2(x+(y-2))^2+3(y+1)^2=$
# $=2((x-3)+(y+1))^2+3(y+1)^2=2((x-3)^2+2(x-3)(y+1)+(y+1)^2)+3(y+1)^2=$
# $=2(x-3)^2+4(x-3)(y+1)+5(y+1)^2$
#
# После преобразования видно, что вектор математических ожиданий будет равен:
#
# $E=\left( \begin{matrix}
# 3   \\
# -1
# \end{matrix}\right)$
#
# Ковариационная матрица в степени -1 будет равна:
#
# $ \Sigma^{-1} = \begin{pmatrix}
# 2 & \ 2\\
# 2 & 5
# \end{pmatrix} $
#
# Найдем обратную матрицу:
#
# $ \Sigma =\frac{1}{6} \begin{pmatrix}
# 5 &-2\\
# -2 & 2
# \end{pmatrix} $
#
# После нахождения ковариационной матрицы необходимо найти дисперсию и ковариацию:
#
# $ cov(\xi, \eta)=-\frac{2}{6}=-\frac{1}{3}$
#
# $\mathbb{D} \xi=\frac{5}{6}$
#
# $\mathbb{D} \eta=\frac{2}{6}=\frac{1}{3}$
#
# Зная дисперсии и ковариацию по формуле найдем коэфицент кореляции:
#
# $ \rho (\xi, \eta) = \cfrac{\mathrm{cov} (\xi, \eta)}{\sqrt{\mathbb{D} \xi \cdot \mathbb{D} \eta}} = -\cfrac{-\frac{1}{3}}{\sqrt{\frac{5}{6} \cdot \frac{1}{3}}} = -\frac{1}{3} \cdot \sqrt{\frac{5}{18}}=-\frac{\sqrt{2}}{5} $
#
# Теперь по формуле вычислим коэфицент C:
#
# $ C = \frac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} = \frac{1}{\left(2\pi\right)^{2/2} \sqrt{\frac{1}{6}}} =\frac{\sqrt{6}}{2\pi} $
#
# После нахождения коэфицента C подставим его в изначальное выражение:
#
# $ p_{\xi, \eta}  (x, y) = \frac{\sqrt{6}}{2\pi} \cdot \exp \left(-\cfrac{1}{2}\left(2x^2+4xy+5y^2-8x-2y+11\right)\right) $
#
# Построим график функции:

# %%
import numpy as np
import matplotlib.pyplot as plt

from math import pi, e, sqrt

x = np.arange(-2, 2, 0.05)
y = np.arange(-2, 2, 0.05)
xgrid, ygrid = np.meshgrid(x, y)
zgrid =  sqrt(6) / (2 * pi) * e ** (-0.5 * (2 * xgrid ** 2 + 4 * xgrid * ygrid + 5 * ygrid ** 2 - 8 * xgrid - 2 * ygrid + 11))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задача №2.
#
# Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# Афинное преобразование:
#
# $ \left(\begin{matrix}
# x\\
# y
# \end{matrix}\right) = A \left(\begin{matrix}
# u\\
# v
# \end{matrix}\right) + \left(\begin{matrix}
# \alpha\\
# \beta
# \end{matrix}\right) $
#
#
# $2(x+y-2)^2+3(y+1)^2=(\sqrt{2}x+\sqrt{2}y-2\sqrt{2})^2+(\sqrt{3}y+\sqrt{3})$
#
# $\left(\begin{matrix}
# u  \\
# v
# \end{matrix}\right)\leftrightarrow \left(\begin{matrix}
# x  \\
# y
# \end{matrix}\right)$
#
# Теперь зная коэфиценты, найдем нромальное распределение:
#
# $ \left(\begin{matrix}
# \xi_{st}\\
# \eta_{st}
# \end{matrix}\right) = \left(\begin{matrix}
# \sqrt{2} & \sqrt{2} \\
# 0 & \sqrt{3}
# \end{matrix}\right) \cdot\left( \begin{matrix}
# \xi   \\
# \eta
# \end{matrix} \right) + \left( \begin{matrix}
# -2\sqrt{2}  \\
# \sqrt{3}
# \end{matrix} \right)=\left( \begin{matrix}
#  \sqrt{2}\xi +\sqrt{2}\eta -2\sqrt{2}  \\
#  \sqrt{3}\eta +\sqrt{3}
# \end{matrix} \right) \rightarrow A=\left(\begin{matrix}
# \sqrt{2} & \sqrt{2} \\
# 0 & \sqrt{3}
# \end{matrix}\right),\left(\begin{matrix}
# \alpha\\
# \beta
# \end{matrix}\right)= \left( \begin{matrix}
# -2\sqrt{2}  \\
# \sqrt{3}
# \end{matrix} \right) $
# Для того чтобы проверить правильность расчетов выполним проверку.
#
#
#
# $Var\left(\begin{matrix}
# \xi_{st}\\
# \eta_{st}
# \end{matrix}\right)=A \cdot \Sigma \cdot A^T \Rightarrow Var\left(\begin{matrix}
# \xi_{st}\\
# \eta_{st}
# \end{matrix}\right)=\frac{1}{6}\left(\begin{matrix}
# \sqrt{2} & \sqrt{2}\\
# 0 & \sqrt{3}
# \end{matrix}\right)\cdot \left(\begin{matrix}
# 5 & -2\\
# -2 & 2
# \end{matrix}\right) \cdot \left(\begin{matrix}
# \sqrt{2} & 0\\
# \sqrt{2} & \sqrt{3}
# \end{matrix}\right)=\frac{1}{6}\left(\begin{matrix}
# 6 & 0\\
# 0 & 6
# \end{matrix}\right)=\left(\begin{matrix}
# 1 & 0\\
# 0 & 1
# \end{matrix}\right)$
#
# ### Задача №3.
#
# Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
# $det(\Sigma^{-1}-\lambda\cdot E)$
# $det \left(\begin{matrix}
# 2-\lambda & 2\\
# 2 & 5-\lambda
# \end{matrix}\right)=(2-\lambda)(5-\lambda)-4=0$
# $10-7\lambda+\lambda^2-4=0 \rightarrow \lambda^2-7\lambda+6=0 \rightarrow (\lambda-1)(\lambda-6)=0$
# $\lambda_1=1, \lambda_2=6$
#
# Найдем два вектора, подставив полученные значения лямбды в исходную матрицу:
#
# При $\lambda_1=1 $ получим следущие значения:
#
# $ \left(\begin{matrix}
# 1 & 2\\
# 2 & 4
# \end{matrix}\right) \rightarrow \begin{equation*}
#                                  \begin {cases}
#                                   x+2y=0\\
#                                  2x+4y=0
#                                   \end{cases}
#                                    \end{equation*}$, при $x=2, y=-1$
#
# Подстваим найденые значения и получим первый собственный вектор:
#
# $\overrightarrow{v_1}=\alpha \left(\begin{matrix}
# 2\\
# -1
# \end{matrix}\right), \alpha=\frac{1}{\sqrt{2^2+1^2}}=\frac{1}{\sqrt{5}} \rightarrow \overrightarrow{v_1}=\frac{1}{\sqrt{5}} \left(\begin{matrix}
# 2\\
# -1
# \end{matrix}\right)$
#
# При $\lambda_2=6 $ получим следущие значения:
#
# $ \left(\begin{matrix}
# 1 & 2\\
# 2 & 4
# \end{matrix}\right) \rightarrow \begin{equation*}
#                                  \begin {cases}
#                                   -4x+2y=0\\
#                                  2x-y=0
#                                   \end{cases}
#                                    \end{equation*}$, при $x=2, y=-1$, при $y=2,x=1 $
#
# Подстваим найденые значения и получим второй собственный вектор:
#
#  $\overrightarrow{v_2}=\frac{1}{\sqrt{5}} \left(\begin{matrix}
#  1\\
# 2
# \end{matrix}\right)$
#
# Теперь зная значения векторов найдем матрицу $Q$ и $ Q^{T} $:
#
# $ Q^{T}= \frac{1}{\sqrt{5}} \left(\begin{matrix}
# 2&-1\\
# 1&2
# \end{matrix}\right) $
#
# $ Q= \frac{1}{\sqrt{5}} \left(\begin{matrix}
# 2&-1\\
# 1&2
# \end{matrix}\right) $
#
# Формула для ортогонального преобразоания:
#
# $\Sigma_{id} = Q \cdot \Sigma \cdot Q^{T} \rightarrow \Sigma_{id}= \frac{1}{\sqrt{5}} \cdot \frac{1}{\sqrt{5}} \cdot \frac{1}{6} \cdot \left(\begin{matrix}
# 2&1\\
# -1&2
# \end{matrix}\right) \cdot  \left(\begin{matrix}
# 5&-2\\
# -2&2
# \end{matrix}\right) \cdot  \left(\begin{matrix}
# 2&-1\\
# 1&2
# \end{matrix}\right)= \frac{1}{30} \cdot \left(\begin{matrix}
# 30&0\\
# 0&5
# \end{matrix}\right)=\left(\begin{matrix}
# 1&0\\
# 0&\frac{1}{6}
# \end{matrix}\right)$
#
# Теперь найдем значения для построения графика:
#
# $E=\left(\begin{matrix}
# \xi\\
# \eta
# \end{matrix}\right)=Q \cdot \overline{\mu}= \frac{1}{\sqrt{5}} \left(\begin{matrix}
# 2&-1\\
# 1&2
# \end{matrix}\right)\left( \begin{matrix}
# 3   \\
# -1
# \end{matrix}\right)=\left( \begin{matrix}
# \frac{7\sqrt{5}}{5}   \\
# \frac{\sqrt{5}}{5}
# \end{matrix}\right),D_{\xi}=1,D_{\eta}=\frac{1}{6}, cov(\xi,\eta)=0 , p(\xi,\eta)=0$
#
# Вычислим функцию для построения графика:
#
# $\Sigma_{id}^{-1} = \left(\begin{matrix}
# 1&0\\
# 0&6
# \end{matrix}\right)$
# $ p_{\xi, \eta}  (x, y) = \frac{1}{2\pi\sqrt{\frac{1}{6}}} \cdot \exp \left(-\cfrac{1}{2}\left(\begin{matrix}
# x - \frac{7\sqrt{5}}{5}&y - \frac{\sqrt{5}}{5}\\
# \end{matrix}\right) \cdot \left(\begin{matrix}
# 1&0\\
# 0&6
# \end{matrix}\right) \cdot \left(\begin{matrix}
# x - \frac{7\sqrt{5}}{5}\\
# y - \frac{\sqrt{5}}{5}
# \end{matrix}\right) \right)=\frac{\sqrt{6}}{2\pi} \cdot \exp \left(-\frac{1}{2}(x^2 - \frac{14\sqrt{5}x}{5} + 11 +6y^2 - \frac{12\sqrt{5}y}{5})\right)$
#
# Теперь построим график:

# %%
x = np.arange(-1, 1, 0.05)
y = np.arange(-1, 1, 0.05)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = sqrt(6) / (2 * pi) * e ** (-0.5 * (xgrid ** 2 - (14 * x * sqrt(5) / 5) + 11 + 6 * ygrid ** 2 - (12 * sqrt(5) * y / 5 )))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задача №4.
#
# Вычислить характеристики совместного распределения случайного вектора $ \left(-5\xi+3\eta, 4\xi+4\eta\right)^{T} $ и записать его плотность. Построить график плотности полученного распределения.
#
#
# Аналагично второй задаче найдем преобразуем вектор с помощью аффиного преобразоания:
# $ \overrightarrow{w}=\left( \begin{matrix}
# -5\xi+3\eta     \\
# 4\xi+4\eta
# \end{matrix} \right)$
#
# $ \left(\begin{matrix}
# \xi_1\\
# \eta_1
# \end{matrix}\right) = A_1 \left(\begin{matrix}
# \xi\\
# \eta
# \end{matrix}\right) + \left(\begin{matrix}
# \alpha_1\\
# \beta_1
# \end{matrix}\right) = \left(\begin{matrix}
# -5\xi+3\eta \\
# 4\xi+4\eta
# \end{matrix}\right)=\left(\begin{matrix}
# -5&3 \\
# 4&4
# \end{matrix}\right) \cdot \left(\begin{matrix}
# \xi \\
# \eta
# \end{matrix}\right)+\left(\begin{matrix}
# 0 \\
# 0
# \end{matrix}\right)$
#
# Математическое ожидание, дисперсия, ковариационная матрица, ковариация, кореляция будут равны:
#
# $E\left(\begin{matrix}
# \xi_1 \\
# \eta_1
# \end{matrix}\right)=\left(\begin{matrix}
# 3 \\
# -1
# \end{matrix}\right)$
#
# $Var=A_1 \cdot \Sigma \cdot A_1^{T} = \frac{1}{6} \cdot \left(\begin{matrix}
# -5&3 \\
# 4&4
# \end{matrix}\right) \cdot \left(\begin{matrix}
# 5&-2 \\
# -2&2
# \end{matrix}\right) \cdot \left(\begin{matrix}
# -5&4 \\
# 3&4
# \end{matrix}\right)=\frac{1}{6} \cdot \left(\begin{matrix}
# 203&-60 \\
# -60&48
# \end{matrix}\right)= \left(\begin{matrix}
# \frac{203}{6}&-10 \\
# -10&8
# \end{matrix}\right)$
#
# $\mathbb{D}(-5\xi+3\eta)=\frac{203}{6} $
#
# $\mathbb{D}(4\xi+4\eta)=8 $
#
# $cov(\xi_1,\eta_1)=-10  $
#
# $\rho (\xi_1, \eta_1) = \cfrac{\mathrm{cov} (\xi_1, \eta_1)}{\sqrt{\mathbb{D} \xi_1 \cdot \mathbb{D} \eta_1}}=-\frac{10}{2\sqrt{2}\cdot\sqrt{\frac{203}{6}}}=-\frac{5\sqrt{6}}{\sqrt{406}} $
#
# Найдем Функцию и построим график:
#
# $det Var=\frac{6144}{36}$
#
# $Var^{-1}=\frac{1}{1024} \cdot \left(\begin{matrix}
# 48&60 \\
# 60&203
# \end{matrix}\right) $
#
# $ p_{\xi_1, \eta_1}  (x, y) = \frac{1}{2\pi \cdot \sqrt{\frac{6144}{36}}} \cdot \exp \left(-\cfrac{1}{2} \cdot \frac{1}{1024} \cdot \left(\begin{matrix}
# x-3 & y+1 \\
# \end{matrix}\right)\cdot \left(\begin{matrix}
# 48&60 \\
# 60&203
# \end{matrix}\right) \cdot \left(\begin{matrix}
# x-3 \\
# y+1
# \end{matrix}\right)\right)= \frac{1}{2\pi \cdot \sqrt{\frac{6144}{36}}} \cdot \exp \left(-\cfrac{1}{2}\left(\frac{3}{64}x^2+\frac{15}{128}xy+\frac{203}{1024}y^2-\frac{21}{128}x-\frac{23}{512}y+\frac{275}{1024}\right)\right)$

# %%
x = np.arange(-20, 20, 0.05)
y = np.arange(-20, 20, 0.05)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 1 / (2 * pi *sqrt(6144/36)) * e ** (-0.5 * (3 / 64 * xgrid ** 2 + 15/128*xgrid*ygrid + 203 / 1024 * ygrid ** 2-21/128*ygrid+275/1024))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %% [markdown]
# ### Задача №5.
#
# Найти условное распределение $ \xi $ при условии $ \eta $. Вычислить $ E \left(\xi|\eta\right) $ и $ D \left(\xi|\eta\right) $.
#
# Сначала найдем условное распределение. Формула для его нахождения выглядит следующим образом:
#
# $\rho_{\xi|\eta}(x)= \frac{\rho_{\xi,\eta}(x,y)}{\rho_\eta(y)}$
#
# Найдем нормальное распределение:
#
# $D_{\eta}=\frac{1}{3} \rightarrow \sigma^2=\frac{1}{3}\rightarrow \sigma=\frac{1}{\sqrt{3}}$
#
# $E_{\eta}= -1 \rightarrow m =-1$
#
# $ p(x)=\cfrac{1}{\sigma\sqrt{2\pi}} \cdot\exp\left(-\frac{1}{2} \left(\frac{(x-m)^2}{(\sigma)^2}\right)\right) \rightarrow  p(y)=\frac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp (-\frac{1}{2}(3y^2+6y+3))$
# Теперь чтобы найти условное распределение необходимо поделить исходное распределение на полученное выше значение $p(y)$:
#
# $\rho_{\xi|\eta}(x)=\frac{\frac{\sqrt{6}}{2\pi}}{\frac{\sqrt{3}}{\sqrt{2\pi}}} \cdot \frac{\exp(-\frac{1}{2}(2x^2+4xy+5y^2-8x-2y+11 ))}{\exp(-\frac{1}{2}(3y^2+6y+3))}=\frac{\sqrt{2}}{\sqrt{2\pi}}\cdot \exp(-\frac{1}{2}(2x^2+4xy+2y^2-8x-8y+8))= $
# $= \frac{\sqrt{2}}{\sqrt{2\pi}}\cdot \exp(-\frac{1}{2}\frac{(x^2+2xy+y^2-4x-4y+4)}{\frac{1}{2}} )= \frac{\sqrt{2}}{\sqrt{2\pi}}\cdot \exp(-\frac{1}{2}\frac{(x^2+2x(y-2)+y^2-4y+4)}{\frac{1}{2}} ) =\frac{\sqrt{2}}{\sqrt{2\pi}}\cdot \exp(-\frac{1}{2}\frac{(x^2+2x(y-2)+(y-2)^2)}{\frac{1}{2}} ) =$
# $= \frac{\sqrt{2}}{\sqrt{2\pi}}\cdot \exp(-\frac{1}{2}\frac{(x+(y-2))^2)}{\frac{1}{2}} )$
#
# Теперь вычислим $ E \left(\xi|\eta\right) $ и $ D \left(\xi|\eta\right) $:
#
# $ E \left(\xi|\eta\right) =-y+2$
#
# $ D \left(\xi|\eta\right) = \frac{1}{2}$

# %% [markdown]
# ## Выводы
#
# При выполнении данной работы были преобретены такие знания как: умение строить графики трехмерных функций, умение находить условное распределение, вычислять характеристики совместного распределения случайного вектора и многое другое. Так же, была освоен редактор jupyter notebook и умение работать в нем. Все пункты задания были успешно выполнены, и были изучены новые навыки. При выполнении работы, возникли трудности с четвертым заданием, но разобравшись в нем более подробно, все ошибки были исправлены.Работа оказалась весьма интересной, даже не смотря на сложности, которые возникли в ходе ее решения.
