# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнилa студентка гр. 2364 Коваль Марина Артёмовна. Вариант №7

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Плотность нормального случайного вектора: $p_{\vec{\xi}}(x_1,...,x_n)=\frac{1}{(2\Pi)^{\frac{n}{2}}\sqrt{det\Sigma}}\exp\left(-\frac{1}{2}(\vec{X}-\mu)^T\Sigma^{-1}(\vec{X}-\mu)\right)$
#
# $\vec{X}=(X_1,...,X_n)^T ,\vec{\xi}=\mathcal{N}(\mu, \Sigma)$
#
# $ A=(a_{ij})_{1\leq i,j\leq n},b=(b_1,...,b_n)^T  $
#
# $ \vec{\eta}=A\vec{\xi}+b\sim \mathcal{N}(A\mu+b,A \Sigma A^T) $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.
#
# Плотность двумерного нормального распределения имеет вид: $$\rho_{\xi,\eta}(x,y)=C\cdot \exp\left(-\frac{1}{2}\left( 6x^2-4xy+9y^2+8x+14y+11 \right)\right)$$

# %% [markdown]
# ## Выполнение работы
#
# Каждый пункт работы выполняется с помощью кода.

# %% [markdown]
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $\rho_{\xi, \eta}$

# %% [markdown]
# $6x^2-4xy+9y^2+8x+14y+11 = 6(x-\frac{1}{3}y)^2+\frac{25}{3}y^2+8x+14y+11 = 6((x-\frac{1}{3}y)+\frac{2}{3})^2+\frac{25}{3}(y+1)^2=$
#
#
# $6(x+1)^2-4(y+1)(x+1)+9(y+1)^2$

# %% [markdown]
# Вектор матожидания:

# %% [markdown]
# $ \mathbb{E}
# \begin{equation*}
# \left(
# \begin{array}{cc}
# \xi\\
# \eta\\
# \end{array}
# \right)
# \end{equation*}$=
# $\begin{equation*}
#        \left( \begin{array} {cc} -1\\ -1\\ \end{array}\right)
# \end{equation*} $

# %% [markdown]
# $ \begin{equation*}
# \Sigma^{-1} = \left(
# \begin{array}{cccc}
# 6 & -2\\
# -2 & 9
# \end{array}
# \right)
# \end{equation*} $

# %% [markdown]
# Ковариационная матрица:
#
# $\begin{equation*}
# \Sigma = \frac{1}{50} \left(
# \begin{array}{cccc}
# 9 & 2\\
# 2 & 6
# \end{array}
# \right)
# \end{equation*}$, $ det\Sigma=\frac{1}{50} $

# %% [markdown]
# $\mathbb D_{\xi}=\frac{9}{50}$
#
# $\mathbb D_{\eta}=\frac{3}{25}$
#
# $cov(\xi, \eta)=\frac{1}{25}$
#
# $P_{\xi, \eta}=\frac{cov(\xi, \eta)}{\sqrt{\mathbb D_{\xi}\cdot\mathbb D_{\eta}}}=\frac{2}{3\sqrt{6}}$

# %% [markdown]
# Значение C:

# %% [markdown]
# $$C=\frac{1}{(2\pi)^{\frac{n}{2}}\cdot \sqrt{det\Sigma}}=\frac{1}{2\pi\cdot \sqrt{\frac{1}{50}}}=\frac{5\sqrt{2}}{2\pi}$$

# %% [markdown]
# Плотность $ \rho_{\xi,\eta}(x,y)$ имеет вид:
#
# $$\rho_{\xi,\eta}(x,y)= \frac{5\sqrt{2}}{2\pi}\cdot \exp\left(-\frac{1}{2}\left( 6x^2-4xy+9y^2+8x+14y+11 \right)\right)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

e = 2.7
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
z = (5*math.sqrt(2)/2*math.pi)*e**((-1/2)*(6*x**2-4*x*y+9*y**2+8*x+14*y+11))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 2. Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.

# %% [markdown]
# $6(x-\frac{1}{3}y+\frac{2}{3})^2+\frac{25}{3}(y+1)^2=(\sqrt{6}x-\frac{\sqrt{6}}{3}y+\frac{2\sqrt{6}}{3})^2+(\frac{5}{\sqrt{3}}y+\frac{5}{\sqrt{3}})^2$

# %% [markdown]
# Матрица аффинного преобразования М и вектор сдвига b:

# %% [markdown]
# $ \begin{equation*}
# M = \left(
# \begin{array}{cccc}
# \sqrt{6} & -\frac{\sqrt{6}}{3}\\
# 0 & \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*} $,
# $\begin{equation*}
# b=\left(
# \begin{array}{cc}
#  \frac{2\sqrt{6}}{3} \\
#   \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# Проверим преобразование нахождением вектора матожидания вектора стандартного нормального распределения:

# %% [markdown]
# $ \begin{equation*}
# \left(
# \begin{array}{cc}
#  \xi_{st} \\
#   \eta_{st}
# \end{array}
# \right)
# \end{equation*} $ = $
# \begin{equation*}
#  \left(
# \begin{array}{cccc}
# \sqrt{6} & -\frac{\sqrt{6}}{3}\\
# 0 & \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*} $
# $ \cdot \begin{equation*}
# \left(
# \begin{array}{cc}
#  \xi \\
#   \eta
# \end{array}
# \right)
# \end{equation*} +$
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  \frac{2\sqrt{6}}{3} \\
#   \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# \sqrt{6} & -\frac{\sqrt{6}}{3}\\
# 0 & \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*} $
# $ \cdot \begin{equation*}
# \left(
# \begin{array}{cc}
#  -1 \\
#   -1
# \end{array}
# \right)
# \end{equation*} +$
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  \frac{2\sqrt{6}}{3} \\
#   \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*}$=
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  0 \\
#   0
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# Проверим преобразование нахождением ковариационной матрицы вектора стандартного нормального распредедения:

# %% [markdown]
# $ \Sigma_{st}=M\Sigma M^T $

# %% [markdown]
# $ \Sigma_{st}= \frac{1}{50}\cdot $
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# \sqrt{6} & -\frac{\sqrt{6}}{3}\\
# 0 & \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*}\cdot $
# $\begin{equation*}
# \left(
# \begin{array}{cccc}
# 9 & 2\\
# 2 & 6
# \end{array}
# \right)
# \end{equation*}\cdot$
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# \sqrt{6} & 0\\
# -\frac{\sqrt{6}}{3}& \frac{5}{\sqrt{3}}
# \end{array}
# \right)
# \end{equation*}= $
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# 1 & 0\\
# 0 & 1
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.

# %% [markdown]
# $ \begin{equation*}
# \Sigma^{-1} = \left(
# \begin{array}{cccc}
# 6 & -2\\
# -2 & 9
# \end{array}
# \right)
# \end{equation*} $, $ det(\Sigma^{-1}-\lambda E)=0 $

# %% [markdown]
# $ \begin{equation*}
#  \left(
# \begin{array}{cccc}
# 6-\lambda & -2\\
# -2 & 9-\lambda
# \end{array}
# \right)
# \end{equation*} $
#
# $ \lambda^2-15\lambda +50=0 $
#
# $ \left[
#       \begin{gathered}
#         \lambda_1=10 \\
#         \lambda_2=5 \\
#       \end{gathered}
# \right.  $
#
# $ \begin{equation*}
# M_{\lambda_1}= \left(
# \begin{array}{cccc}
# 6-10 & -2\\
# -2 & 9-10
# \end{array}
# \right)
# \end{equation*}= $
# $ \begin{equation*}
#  \left(
# \begin{array}{cccc}
# -4 & -2\\
# -2 & -1
# \end{array}
# \right)
# \end{equation*}$
#
# $ \begin{equation*}
# M_{\lambda_2}= \left(
# \begin{array}{cccc}
# 6-5 & -2\\
# -2 & 9-5
# \end{array}
# \right)
# \end{equation*}= $
# $ \begin{equation*}
#  \left(
# \begin{array}{cccc}
# 1 & -2\\
# -2 & 4
# \end{array}
# \right)
# \end{equation*}$
#
# $ \begin{equation*}
#  \left(
# \begin{array}{cccc}
# -4 & -2\\
# -2 & -1
# \end{array}
# \right)
# \end{equation*}\cdot$
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  x_1 \\
#   x_2
# \end{array}
# \right)
# \end{equation*}=0$
#
# $ \vec{V_1}=\alpha \cdot $
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  1 \\
#   -2
# \end{array}
# \right)
# \end{equation*}, $ где $ \alpha =\frac{1}{\sqrt{1^2+(-2)^2}}=\frac{1}{\sqrt{5}} $
#
# $ \begin{equation*}
#  \left(
# \begin{array}{cccc}
# 1 & -2\\
# -2 & 4
# \end{array}
# \right)
# \end{equation*}\cdot$
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  x_1 \\
#   x_2
# \end{array}
# \right)
# \end{equation*}=0$
#
# $ \vec{V_2}=\alpha \cdot $
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  2 \\
#   1
# \end{array}
# \right)
# \end{equation*}, $ где $ \alpha =\frac{1}{\sqrt{1^2+(2)^2}}=\frac{1}{\sqrt{5}} $

# %% [markdown]
# Получим матрицу ортогонального преобразования:

# %% [markdown]
# $ \begin{equation*}
# Q^T=\frac{1}{\sqrt{5}} \left(
# \begin{array}{cccc}
# 2 & 1\\
# 1 & -2
# \end{array}
# \right)
# \end{equation*} $
#
# $ \begin{equation*}
# Q=\frac{1}{\sqrt{5}} \left(
# \begin{array}{cccc}
# 2 & 1\\
# 1 & -2
# \end{array}
# \right)
# \end{equation*} $

# %% [markdown]
# Вычислим ковариационную матрицу для вектора с независимыми компонентами:

# %% [markdown]
# $ \Sigma_{id}= \frac{1}{50}\cdot \frac{1}{5} $
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# 2 & 1\\
# 1 & -2
# \end{array}
# \right)
# \end{equation*}\cdot $
# $\begin{equation*}
# \left(
# \begin{array}{cccc}
# 9 & 2\\
# 2 & 6
# \end{array}
# \right)
# \end{equation*}\cdot$
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# 2 & 1\\
# 1 & -2
# \end{array}
# \right)
# \end{equation*}= $
# $\begin{equation*}
#  \left(
# \begin{array}{cccc}
# \frac{1}{5} & 0\\
# 0 & \frac{1}{10}
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# На главной диагонали стоят элементы, обратные найденным собственным числам, значит ортогональное преобразование получено верно. Построим функцию плотности:

# %% [markdown]
# $p_{\xi_{id},\eta_{id}}(x,y)=\frac{1}{(2\Pi)^{\frac{n}{2}}\sqrt{det\Sigma_{id}}}\exp\left(-\frac{1}{2}(\vec{X}-\mu)^T\Sigma^{-1}(\vec{X}-\mu)\right)$, где
# $ det\Sigma_{id}=\frac{1}{50},$
# $\begin{equation*}
#  \Sigma^{-1}_{id}=\left(
# \begin{array}{cccc}
# 5 & 0\\
# 0 & 10
# \end{array}
# \right)
# \end{equation*},\vec{\mu}= $
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  0 \\
#   0
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# Подставив полученные значения, получим:

# %% [markdown]
# $$\rho_{\xi_{id},\eta_{id}}(x,y)= \frac{5\sqrt{2}}{2\pi}\cdot \exp\left(-\frac{1}{2}\left(5x^2+10y^2\right)\right)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

e = 2.7
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
z = (5*math.sqrt(2)/2*math.pi)*e**((-1/2)*(5*x**2+10*y**2))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 4. Вычислить характеристики совместного распределения случайного вектора $ (-4\xi-5\eta, -4\xi+4\eta)^T $ и записать его плотность. Построить график плотности полученного распределения.

# %% [markdown]
# Так как исходный вектор $ \vec{z}=(-4\xi-5\eta, -4\xi+4\eta)^T$ зависит от параметров $\xi $ и $ \eta $, имеющих нормальное распределение, вектор $ \vec{z} $ также имеет нормальное распределение. По свойству $ \vec{z} = A\vec{\xi}+b\sim \mathcal{N}(A\mu+b,A \Sigma A^T)$

# %% [markdown]
# $ \begin{equation*}
# A= \left(
# \begin{array}{cccc}
# -4 & -5\\
# -4 & 4
# \end{array}
# \right)
# \end{equation*} $
#
# $ \vec{\mu_z}= A\cdot \mu $
#
# $ \begin{equation*}
# \vec{\mu_z}= \left(
# \begin{array}{cccc}
# -4 & -5\\
# -4 & 4
# \end{array}
# \right)
# \end{equation*} \cdot$
# $ \begin{equation*}
# \left(
# \begin{array}{cc}
# -1\\
# -1
# \end{array}
# \right)
# \end{equation*}= $
# $ \begin{equation*}
# \left(
# \begin{array}{cc}
# 9\\
# 0
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# $ \Sigma_z=
#  \begin{equation*}
# \frac{1}{50}\cdot \left(
# \begin{array}{cccc}
# -4 & -5\\
# -4 & 4
# \end{array}
# \right)
# \end{equation*}\cdot $
# $ \begin{equation*}
# \left(
# \begin{array}{cccc}
# 9 & 2\\
# 2 & 6
# \end{array}
# \right)
# \end{equation*}\cdot$
#  $\begin{equation*}
# \left(
# \begin{array}{cccc}
# -4 & -4\\
# -5 & 4
# \end{array}
# \right)
# \end{equation*}= $
# $ \begin{equation*}
#  \frac{1}{25} \left(
# \begin{array}{cccc}
# 187 & 16\\
# 16 & 88
# \end{array}
# \right)
# \end{equation*} $

# %% [markdown]
# Вычислим характеристики совместного распределения, обозначая $ \alpha=-4\xi-5\eta, \beta=-4\xi+4\eta $:

# %% [markdown]
# $\mathbb D_{\alpha}=\frac{187}{25}$
#
# $\mathbb D_{\beta}=\frac{88}{25}$
#
# $cov(\alpha, \beta)=\frac{16}{25}$
#
# $P_{\xi, \eta}=\frac{cov(\alpha, \beta)}{\sqrt{\mathbb D_{\alpha}\cdot\mathbb D_{\beta}}}=\frac{8}{11\sqrt{34}}$

# %% [markdown]
# Вычислим плотность совместного распределения вектора $ \vec{z}$:

# %% [markdown]
# $p_{\alpha,\beta}(x,y)=\frac{1}{(2\Pi)^{\frac{n}{2}}\sqrt{det\Sigma_{z}}}\exp\left(-\frac{1}{2}(\vec{X}-\mu)^T\Sigma^{-1}(\vec{X}-\mu)\right)$, где
# $ det\Sigma_{z}=\frac{648}{25},$
# $\begin{equation*}
#  \Sigma^{-1}_{z}=\left(
# \begin{array}{cccc}
# \frac{11}{81} & -\frac{2}{81}\\
# -\frac{2}{81} & \frac{187}{648}
# \end{array}
# \right)
# \end{equation*},\vec{\mu_z}= $
# $\begin{equation*}
# \left(
# \begin{array}{cc}
#  9 \\
#   0
# \end{array}
# \right)
# \end{equation*}$

# %% [markdown]
# Подставив полученные значения, получим:

# %% [markdown]
# $$\rho_{\alpha,\beta}(x,y)= \frac{5}{36\sqrt{2}\pi}\cdot \exp\left(-\frac{1}{2}\left(\frac{11}{81}x^2-\frac{22}{9}x-\frac{4}{81}xy+\frac{4}{9}y+\frac{187}{648}y^2-20y+11\right)\right)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

e = 2.7
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
z = (5/36*math.sqrt(2)*math.pi)*e**((-1/2)*((11/81)*x**2-(22/9)*x-(4/81)*x*y+(4/9)*y+(187/648)*y**2+11))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 5. Найти условное распределение $ \xi $ при условии $ \eta $. Вычислить $ \mathbb{E}(\xi|\eta) $ и $ \mathbb{D}(\xi|\eta). $

# %% [markdown]
# Плотность распределения  $ \xi $ при условии $ \eta $:
#
# $ \rho_{\xi|\eta=y_0}(x)=\frac{\rho_{\xi,\eta}(x,y_0)}{\rho_{\eta}(y_0)} $
#
# $ \rho_{\eta}(y_0)=\int_{-\infty}^{+\infty}\rho_{\xi,\eta}(x,y)dx = \frac{\sqrt{2\pi}}{\sigma_{\eta}}exp\left(-\frac{1}{2}\cdot\left(\frac{y-a_{\eta}}{\sigma_{\eta}}\right)^2  \right) $
#
# $$ \frac{\rho_{\xi,\eta}(x,y_0)}{\rho_{\eta}(y_0)}=\frac{\frac{5\sqrt{2}}{2\pi}\cdot \exp\left(-\frac{1}{2}\left( 6x^2-4xy_0+9y_0^2+8x+14y_0+11 \right)\right)}{\frac{5\sqrt{2\pi}}{\sqrt{3}}\exp\left(-\frac{1}{2}\cdot\left(\frac{y+1}{\frac{\sqrt{3}}{5}}\right)^2  \right)}   $$

# %% [markdown]
# Преобразовав дробь $ \frac{\rho_{\xi,\eta}(x,y_0)}{\rho_{\eta}(y_0)}  $, получим:

# %% [markdown]
# $$ \rho_{\xi|\eta=y_0}(x)= \frac{\sqrt{3\pi}}{\pi}\exp\left(-\frac{1}{2}\cdot\left(\frac{x-(\frac{y_0-2}{3})}{\frac{1}{\sqrt{6}}}\right)^2  \right) $$

# %% [markdown]
# Тогда $ \mathbb{E}(\xi|\eta)=\frac{y_0-2}{3} $
#
# $ \mathbb{D}(\xi|\eta)=\frac{1}{6} $

# %% [markdown]
# ## Выводы
#
# В ходе практической работы были рассмотрены и изучены различные виды многомерных нормальных распределений, их свойства, числовые характеристики и способы преобразований. В соответсвии с полученными плотностями распределения были построены двумерные графики, которые представляют собой "шляпу Гаусса", характерную для нормального распределения. Заметно, что в случае центрированного случайного вектора график плотности распределения кривая Гаусса располагается именно в начале координат из-за нулевого матожидания. В работе также показано, что благодаря свойству линейности двух зависимых случайных нормальных векторов, можно легко произвести любые необходимые преобразования над исходным случайным вектором.
