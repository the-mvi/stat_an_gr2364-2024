# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2364 Петриченко Данил Алексеевич. Вариант №12

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# **Многомерное нормальное распределение**
#
# Случайный вектор $\overrightarrow{\xi} = \left(\xi_1,\dots , \xi_n\right)^T$ имеет многомерное нормальное распределение, если $\exists$ вектор независимых стандартных случайных вероятностей $\overrightarrow{\zeta}=\left(\zeta_1,\dots , \zeta_n\right)^T$, вещественный вектор $\overrightarrow{\mu}=\left(\mu_1,\dots , \mu_n\right)^T$ и ненулевая матрица $A$ размерности $m\times n$, такие, что:
#
# $\overrightarrow{\xi} = A\overrightarrow{\zeta}+\overrightarrow{\mu}$
#
# $\overrightarrow{\xi}\sim\mathcal{N}\left(\mu,\Sigma\right)$
#
# $\overrightarrow{\mu} = \overrightarrow{\mathbb{E}_{\xi}} = \left(\mathbb{E}_{\xi_1},\dots , \mathbb{E}_{\xi_n}\right)^T$ - вектор математических ожиданий
#
# $\Sigma = \left(\sigma_{ij}\right)_{i \leq i,j \leq n}, \sigma_{ij} = \mathrm{cov}(\xi_i,\xi_j)$ - матрица ковариаций
#
# **Плотность нормального случайного вектора**
#
# $p_{\overrightarrow{\xi}}(x_1,\dots, x_n)=\cfrac{1}{\left(2\pi\right)^{n/2}\sqrt{det\left(\Sigma\right)}}\cdot\exp\left(-\cfrac{1}{2}\left(\overrightarrow{x} - \mu\right)^T\Sigma^{-1}\left(\overrightarrow{x} - \mu\right)\right)$
#
# $\overrightarrow{\xi}\sim\mathcal{N}\left(\mu,\Sigma\right)$
#
# $\overrightarrow{\eta}=A\overrightarrow{\xi}+b$
#
# $\mathbb{E}\overrightarrow{\eta}=A\mu+b$
#
# $\mathrm{Var}\left(\overrightarrow{\eta}\right)=A\Sigma A^{\intercal}$

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
#
# ### №1
#
# Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $p_{\xi, \eta}$
#
# $p_{\xi, \eta} = C\cdot\exp\left(-\cfrac{1}{2}\left(3x^2-4xy+6y^2-10x-12y+27\right)\right)$
#
# $3x^2-4xy+6y^2-10x-12y+27=\cfrac{9}{3}x^2-\cfrac{12}{3}xy+\cfrac{4}{3}y^2+\cfrac{14}{3}y^2-10x-12y+27=\cfrac{1}{3}\left(9x^2-12xy+4y^2\right)+\cfrac{14}{3}y^2-10x-12y+27=\cfrac{1}{3}\left(3x-2y\right)^2+\cfrac{14}{3}y^2-\cfrac{30}{3}x+\cfrac{20}{3}y+\cfrac{25}{3}+\cfrac{56}{3}-\cfrac{56}{3}y=\cfrac{1}{3}\left(\left(3x-2y\right)^2-30x+20y+25\right)+\cfrac{14}{3}y^2-\cfrac{56}{3}y+\cfrac{56}{3}=\cfrac{1}{3}\left(\left(3x-2y\right)^2-10\left(3x-2y\right)+25\right)+\cfrac{14}{3}\left(y^2-4y+4\right)=\cfrac{1}{3}\left(3x-2y-5\right)^2+\cfrac{14}{3}\left(y-2\right)^2$
#
# $\cfrac{1}{3}\left(3x-2y-5\right)^2+\cfrac{14}{3}\left(y-2\right)^2=\cfrac{1}{3}\left(\left(3x-9\right)-2\left(y-2\right)\right)^2+\cfrac{14}{3}\left(y-2\right)^2=\cfrac{1}{3}\left(9\left(x-3\right)^2-2\cdot6\left(x-3\right)\left(y-2\right)+4\left(y-2\right)^2\right)+\cfrac{14}{3}\left(y-2\right)^2=3\left(x-3\right)^2-4\left(x-3\right)\left(y-2\right)+6\left(y-2\right)^2$
#
# $C=\cfrac{1}{\left(2\pi\right)^{n/2}\sqrt{\det\Sigma}}=\cfrac{1}{2\pi\sqrt{\cfrac{1}{14}}}=\cfrac{\sqrt{14}}{2\pi}$
#
# $\mathbb{E}\begin{pmatrix}\xi\\\eta\end{pmatrix}=\begin{pmatrix}3\\2\end{pmatrix}$
#
# $\Sigma^{-1}=\begin{pmatrix}3&-2\\-2&6\end{pmatrix}$
#
# $\Sigma=\cfrac{1}{14}\begin{pmatrix}6&2\\2&3\end{pmatrix}$
#
# $\mathbb{D}\xi=\cfrac{3}{7}$
#
# $\mathbb{D}\eta=\cfrac{3}{14}$
#
# $\mathrm{cov}\left(\xi,\eta\right)=\cfrac{1}{7}$
#
# С учётом константы:
#
# $p_{\xi,\eta}(x,y)=\cfrac{\sqrt{14}}{2\pi}\cdot\exp\left(-\cfrac{1}{2}\left(3x^2-4xy+6y^2-10x-12y+27\right)\right)$

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x, y = np.meshgrid(np.arange(1, 5, 0.1), np.arange(0, 4, 0.1))
z = 14 ** 0.5 / (2 * pi) * e ** (-0.5 * (3 * x ** 2 - 4 * x * y + 6 * y ** 2 - 10 * x - 12 * y + 27))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(x, y, z, color='blue')
plt.show()

# %% [markdown]
# ### №2
#
# Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# $\cfrac{1}{3}\left(3x-2y-5\right)^2+\cfrac{14}{3}\left(y-2\right)^2=\left(\cfrac{3}{\sqrt{3}}x-\cfrac{2}{\sqrt{3}}y-\cfrac{5}{\sqrt{3}}\right)^2+\left(\cfrac{\sqrt{14}}{\sqrt{3}}y-\cfrac{2\sqrt{14}}{\sqrt{3}}\right)^2$
#
# $\begin{pmatrix}\xi_{ст}\\\eta_{ст}\end{pmatrix}=\begin{pmatrix}\cfrac{3}{\sqrt{5}}&-\cfrac{2}{\sqrt{3}}\\0&\cfrac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix}\xi\\\eta\end{pmatrix}+\begin{pmatrix}-\cfrac{5}{\sqrt{3}}\\-\cfrac{2\sqrt{14}}{\sqrt{3}}\end{pmatrix}$
#
# Проверка:
#
# $\mathbb{E}\begin{pmatrix}\xi_{ст}\\\eta_{ст}\end{pmatrix}=\begin{pmatrix}\cfrac{3}{\sqrt{5}}&-\cfrac{2}{\sqrt{3}}\\0&\cfrac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix}3\\2\end{pmatrix}+\begin{pmatrix}-\cfrac{5}{\sqrt{3}}\\-\cfrac{2\sqrt{14}}{\sqrt{3}}\end{pmatrix}=\begin{pmatrix}\cfrac{9}{\sqrt{3}}-\cfrac{4}{\sqrt{3}}-\cfrac{5}{\sqrt{3}}\\\cfrac{2\sqrt{14}}{\sqrt{3}}-\cfrac{2\sqrt{14}}{\sqrt{3}}\end{pmatrix}=\begin{pmatrix}0\\0\end{pmatrix}$
#
# $\mathrm{Var}\begin{pmatrix}\xi_{ст}\\\eta_{ст}\end{pmatrix}=\cfrac{1}{14}\begin{pmatrix}\cfrac{3}{\sqrt{5}}&-\cfrac{2}{\sqrt{3}}\\0&\cfrac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix}6&2\\2&3\end{pmatrix}\begin{pmatrix}\cfrac{3}{\sqrt{5}}&0\\-\cfrac{2}{\sqrt{3}}&\cfrac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}=\cfrac{1}{14}\begin{pmatrix}\cfrac{14}{\sqrt{3}}&0\\\cfrac{2\sqrt{14}}{\sqrt{3}}&\cfrac{3\sqrt{14}}{\sqrt{3}}\end{pmatrix}\begin{pmatrix}\cfrac{3}{\sqrt{5}}&0\\-\cfrac{2}{\sqrt{3}}&\cfrac{\sqrt{14}}{\sqrt{3}}\end{pmatrix}=\cfrac{1}{14}\begin{pmatrix}14&0\\0&14\end{pmatrix}=\begin{pmatrix}1&0\\0&1\end{pmatrix}$

# %% [markdown]
# ### №3
#
# Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
# $\begin{pmatrix}3-\lambda&-2\\-2&6-\lambda\end{pmatrix}=\left(3-\lambda\right)\left(6-\lambda\right)-4=18-3\lambda-6\lambda+\lambda^2-4=0\Rightarrow$
#
# $\lambda^2-9\lambda+14=0$
#
# $81-56=25=5^2$
#
# $\lambda_{1,2}=\cfrac{9\pm5}{2}$
#
# $\lambda_1=\cfrac{9+5}{2}=7$
#
# $\lambda_2=\cfrac{9-5}{2}=2$
#
# $A_1=\begin{pmatrix}-4&-2\\-2&-1\end{pmatrix},A_2=\begin{pmatrix}1&-2\\-2&4\end{pmatrix}$
#
# $\begin{cases}-4x-2y=0\\-2x-y=0\end{cases},\begin{cases}x-2y=0\\-2x+4y=0\end{cases}$
#
# $u_1=\alpha\begin{pmatrix}1\\-2\end{pmatrix},u_2=\alpha\begin{pmatrix}2\\1\end{pmatrix}$
#
# $\alpha=\cfrac{1}{\sqrt{1+2^2}}=\cfrac{1}{\sqrt{5}}$
#
# $Q^{\intercal}=\cfrac{1}{\sqrt{5}}\begin{pmatrix}1&2\\-2&1\end{pmatrix}$
#
# $Q=\cfrac{1}{\sqrt{5}}\begin{pmatrix}1&-2\\2&1\end{pmatrix}$
#
# $\Sigma_{id}=Q\Sigma Q^{\intercal}=\cfrac{1}{14}\cdot\cfrac{1}{5}\begin{pmatrix}1&-2\\2&1\end{pmatrix}\begin{pmatrix}6&2\\2&3\end{pmatrix}\begin{pmatrix}1&2\\-2&1\end{pmatrix}=\cfrac{1}{70}\begin{pmatrix}2&-4\\14&7\end{pmatrix}\begin{pmatrix}1&2\\-2&1\end{pmatrix}=\cfrac{1}{70}\begin{pmatrix}10&0\\0&35\end{pmatrix}=\begin{pmatrix}\cfrac{1}{7}&0\\0&\cfrac{1}{2}\end{pmatrix}$
#
# $\Sigma^{-1}_{id}=14\begin{pmatrix}\cfrac{1}{2}&0\\0&\cfrac{1}{7}\end{pmatrix}$
#
# $\mathbb{E}_{id}=Q\mathbb{E} = \cfrac{1}{\sqrt{5}}\cdot\begin{pmatrix}1&-2\\2&1\end{pmatrix}\cdot\begin{pmatrix}3\\2\end{pmatrix} = \cfrac{1}{\sqrt{5}}\cdot\begin{pmatrix}-1\\8\end{pmatrix}$
#
# $p\left(x,y\right)=\cfrac{\sqrt{14}}{2\pi}\cdot\exp\left(-\cfrac{1}{2}\left(7x^2+2y^2+\cfrac{14}{\sqrt{5}}x-\cfrac{32}{\sqrt{5}}y+27\right)\right)$

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x, y = np.meshgrid(np.arange(-2, 1, 0.1), np.arange(0, 5, 0.1))
z = 14 ** 0.5 / (2 * pi) * e ** (-0.5 * (7 * x ** 2 + 2 * y ** 2 + (14/(5 ** 0.5)) * x - (32/(5 ** 0.5)) * y + 27))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(x, y, z, color='blue')
plt.show()

# %% [markdown]
# ### №4
#
# Вычислить характеристики совместного распределения случайного вектора $\begin{pmatrix}2\xi-\eta\\-5\xi-3\eta\end{pmatrix}$ и записать его плотность. Построить график плотности полученного распределения.
#
# $\begin{pmatrix}2\xi-\eta\\-5\xi-3\eta\end{pmatrix}=\begin{pmatrix}2&-1\\-5&-3\end{pmatrix}\begin{pmatrix}\xi\\\eta\end{pmatrix}+\begin{pmatrix}0\\0\end{pmatrix}$
#
# $\mathbb{E}\left(\overrightarrow{\gamma}\right)=\begin{pmatrix}2&-1\\-5&-3\end{pmatrix}\begin{pmatrix}3\\2\end{pmatrix}=\begin{pmatrix}4\\-21\end{pmatrix}$
#
# $\mathrm{Var}\left(\overrightarrow{\gamma}\right)=\cfrac{1}{14}\begin{pmatrix}2&-1\\-5&-3\end{pmatrix}\begin{pmatrix}6&2\\2&3\end{pmatrix}\begin{pmatrix}2&-5\\-1&-3\end{pmatrix}=\cfrac{1}{14}\begin{pmatrix}19&-53\\-53&237\end{pmatrix}$
#
# $\Sigma^{-1}=\cfrac{1}{121}\begin{pmatrix}237&53\\53&19\end{pmatrix}$
#
# $p(x,y)=\cfrac{\sqrt{14}}{22\pi}\cdot\exp\left(-\cfrac{1}{2}\left(\cfrac{237}{121}x^2+\cfrac{30}{11}x+27+\cfrac{106}{121}xy+\cfrac{34}{11}y+\cfrac{19}{121}y^2\right)\right)$

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi, e

x, y = np.meshgrid(np.arange(0, 8, 0.1), np.arange(-42, 0, 0.5))
z = 14 ** 0.5 / (22 * pi) * e ** (-0.5 * (237 / 121 * (x) ** 2 + 30 / 11 * x + 27 + 106 / 121 * (x) * (y) + 34 / 11 * y + 19 / 121 * (y) ** 2))
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_surface(x, y, z, color='blue')
plt.show()

# %% [markdown]
# ### №5
#
# Найти условное распределение $\xi$ при условии $\eta$ . Вычислить $\mathbb{E}_{\left.\xi\right|\eta}$ и $\mathbb{D}_{\left.\xi\right|\eta}$ .
#
# $p_{\xi|\eta=y_0}(x)=\cfrac{p_{\xi,\eta}(x,y_0)}{p_{\eta}(y_0)}=\cfrac{\cfrac{\sqrt{14}}{2\pi}\cdot\exp\left(-\cfrac{1}{2}\left(3x^2-4xy_0+6y_0^2-10x-12y_0+27\right)\right)}{\cfrac{1}{\sqrt{\cfrac{3}{14}}\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\left(\cfrac{y_0-2}{\sqrt{\cfrac{3}{14}}}\right)^2\right)}=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\left(3x^2-4xy_0+\cfrac{4}{3}y_0^2-10x+\cfrac{20}{3}y_0+\cfrac{25}{3}\right)\right)$
#
# По свойству нормального распределения:
#
# $\sigma=\cfrac{1}{\sqrt{3}} \implies \mathbb{D}(\xi|\eta)=\cfrac{1}{3}$
#
# $p_{\xi|\eta=y_0}(x)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\left(3x^2-4xy_0+\cfrac{4}{3}y_0^2-10x+\cfrac{20}{3}y_0+\cfrac{25}{3}\right)\right)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\cdot 3\left(x^2-\cfrac{4}{3}xy_0+\cfrac{4}{9}y_0^2-10x+\cfrac{20}{9}y_0+\cfrac{25}{9}\right)\right)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\cdot 3\left(x^2-2\left(\cfrac{2}{3}y_0-\cfrac{5}{3}\right)x+\cfrac{1}{9}\left(4y_0^2+20y_0+25\right)\right)\right)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\cdot 3\left(x^2-2\left(\cfrac{2y_0+5}{3}\right)x+\left(\cfrac{2y_0+5}{3}\right)^2\right)\right)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\cdot 3\left(x-\cfrac{2y_0+5}{3}\right)^2\right)=\cfrac{\sqrt{3}}{\sqrt{2\pi}}\cdot\exp\left(-\cfrac{1}{2}\cdot\left(\cfrac{x-\cfrac{2y_0+5}{3}}{\left(\cfrac{1}{\sqrt{3}}\right)}\right)^2\right)$
#
# По свойству нормального распределения:
#
# $\mathbb{E}_{\left.\xi\right|\eta} = \cfrac{2y_0+5}{3}$

# %% [markdown]
# ## Выводы
# При выполнении работы для заданного двумерного нормального вектора были вычислены числовые характеристики и были выполнены заданные ортогональное и афинное преобразования. Также были построены графики плотности на основе полученных вычислений. Данные графики являются графиками плотности нормального случайного вектора.
