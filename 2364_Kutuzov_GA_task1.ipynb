# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2364 Кутузов Глеб Александрович. Вариант №8

# %% [markdown]
# # Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
#
# Случайный вектор $\vec{\xi} = \left(\xi_1, \xi_2, ..., \xi_n \right)^{\intercal} : \Omega \rightarrow \mathbb{R}^n $ имеет **многомерное номальное распределение**, если существует вектор независимых стандартных нормальных случайных величин $\vec{\zeta} = \left(\zeta_1, ..., \zeta_m \right)^T $, вещественный вектор $\vec{\mu} = \left(\mu_1, ... , \mu_n \right)^{\intercal} $ и нулевая матрица $ A $ размерности $n \times m$, такие, что $\vec{\xi} = A\vec{\zeta} + \mu $
#
# Вектор математических ожиданий:
#
# $\mu = \mathbb(E){\vec{\xi}} = (\mathbb(E)\xi_1, ..., \mathbb(E)\xi_n)^{\intercal} $
#
# Матрица ковариаций:
#
# $\Sigma = (\sigma_{ij})_{1 \leq ij \leq n}, \sigma_{ij} = cov(\xi_i, \xi_j)$
#
# Плотность нормального случайного вектора:
#
# $ p_{\vec{\xi}}(x_1, .., x_n) = \frac{1}{(2\pi)^{n/2}\sqrt{det(\Sigma)}}exp(-\frac{1}{2}(\vec{x} - \mu)^{\intercal} \Sigma^{-1}(\vec{x}-\mu)) $
#
# Афинное преобразование:
#
# Преобразование, которое переводит вектор в стандартный нормальный.

# %% [markdown]
# # Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# # Выполнение работы

# %% [markdown]
# Плотность двумерного нормального распределения имеет вид:
#
# $p_{\xi,\eta}(x,y) = C \cdot exp\left(-\frac{1}{2}(3x^2-3xy+7y^2+15x+5y+25)\right)$

# %% [markdown]
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $p_{\xi,\eta}$.
# 2. Найти аффионное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотонсти полученного распределения.
# 4. Вычислить характеристики совместного распределения случайного вектора $(-\xi+\eta, -\xi+3\eta)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.
# 5. Найти условное распределение $\xi$ при условии $\eta$. Вычилить $\mathbb E(\xi|\eta)$ и $\mathbb D(\xi|\eta)$.

# %% [markdown]
# Задание 1.
#
# $ p_{\xi,\eta}(x,y) = C \cdot exp\left(-\frac{1}{2}(3x^2-3xy+7y^2+15x+5y+25)\right)$
#
# $ 3x^2-3xy+7y^2+15x+5y+25 = (3x^2 - 3xy+\frac{3}{4}y^2) + \frac{27}{4}y^2 + 15x + 5y + 25 = 3(x-\frac{1}{2}y)^2 - \frac{3}{4}y^2 + 7y^2 + 15x + 5y + 25=$
# $ = 3((x-\frac{1}{2}y)^2 + 5(x-\frac{1}{2}) + \frac{5^2}{2^2}) + \frac{25}{4}(y^2 + 2y + 1) = 3(x-\frac{1}{2}y + \frac{5}{2})^2 + \frac{25}{4}(y+1)^2 = 3((x+3) - \frac{1}{2}(y+1))^2 + \frac{25}{4}(y+1)^2 = $
# $ = 3(x+3)^2 - 3(x+3)(y+1) + 7(y+1)^2 $
#
# Вектор математических ожиданий:
#
# $ \mathbb{E} (\xi , \eta)^{\intercal} = (-3 , -1)^{\intercal}$
#
# $\Sigma^{-1} =
# \begin{pmatrix}
#   3 & -\frac{3}{2}\\
#   -\frac{3}{2} & 7
# \end{pmatrix}$
#
# $ det (\Sigma) = \frac{4}{75}$
#
#
# $ \Sigma = \frac{4}{75}
# \begin{pmatrix}
#   7 & \frac{3}{2}\\
#   \frac{3}{2} & 3
# \end{pmatrix} $
#
# Проверим:
#
# $ \Sigma \cdot \Sigma^{-1} =
# \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix}$
#
#
# $ \mathbb{D}{\xi} =  \frac{28}{75}, \mathbb{D}{\eta} = \frac{12}{75}$
#
# $ cov(\xi, \eta) = \frac{12}{150} = \frac{2}{25}$
#
# $\rho(\xi, \eta) = \frac{cov(\xi, \eta)}{\sqrt{\mathbb{D}\xi \cdot \mathbb{D}\eta}} = \frac{\sqrt{21}}{14}$
#
# $ C = \frac{1}{(2\pi)^{\frac{n}{2}}\cdot\sqrt{det(\Sigma)}} = \frac{5\sqrt{3}}{\pi \cdot 4} $
#
# $ p_{\xi, \eta}(x,y) = \frac{5\sqrt{3}}{\pi \cdot 4} * exp(-\frac{1}{2}(3(x+3)^2 - 3(x+3)(y+1) + 7(y+1)^2)$

# %%
from math import pi, e, sqrt
import matplotlib.pyplot as plt

import numpy as np


os_x = np.arange(-5, 3, 0.2)
os_y = np.arange(-5, 2, 0.2)
x, y = np.meshgrid(os_x, os_y)
os_z = 5 * sqrt(3) / (4 * pi) * e ** (-0.5 * ( 3 * (x +3) ** 2 - 3 * (x + 3) * (y + 1) + 7 * (y + 1) ** 2))
pic = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(x, y, os_z)
plt.show()

# %% [markdown]
# Задание 2.
#
# $ 3(x-\frac{1}{2}y+\frac{5}{2})^2 + \frac{25}{4}(y+1)^2 = (\sqrt{3}x - \frac{\sqrt{3}}{2}y + \frac{5 \cdot \sqrt{3}}{2})^2 + (\frac{5}{2}y + \frac{5}{2})^2 $
#
# $
# \begin{pmatrix}
#   \xi_{st} \\
#   \eta_{st}
# \end{pmatrix} =
# \begin{pmatrix}
#     \sqrt{3} & -\frac{\sqrt{3}}{2}\\
#     0 & \frac{5}{2}
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
#     \xi \\
#     \eta
# \end{pmatrix}
# +
# \begin{pmatrix}
#     \frac{5\sqrt{3}}{2} \\
#     \frac{5}{2}
# \end{pmatrix} =
# \begin{pmatrix}
#     \sqrt{3}\xi -\frac{\sqrt{3}}{2}\eta +\frac{5\sqrt{3}}{2}\\
#     \frac{5}{2}\eta + \frac{5}{2}
# \end{pmatrix}
# $
#
# $ \Sigma_{st} = M \cdot \Sigma \cdot M^{\intercal} =
# \begin{pmatrix}
#     1 & 0 \\
#     0 & 1
# \end{pmatrix}$

# %% [markdown]
# Задание 3.
#
# $ \Sigma^{-1} - \vec{\lambda} =
# \begin{pmatrix}
#     3 - \lambda & -\frac{3}{2} \\
#     -\frac{3}{2} & 7 - \lambda
# \end{pmatrix}$
#
# $ det(\Sigma^{-1} - \vec{\lambda}) = \lambda^2 - 10\lambda + \frac{75}{4}$
#
# $ \lambda^2 - 10\lambda + \frac{75}{4} = 0, D = 5^2$
#
# $ \lambda_1 = \frac{15}{2}, \lambda_2 = \frac{5}{2}$
#
# Для $\lambda_1$:
#
# $
# \begin{pmatrix}
#     -\frac{9}{2} & -\frac{3}{2} \\
#     -\frac{3}{2} & -\frac{1}{2}
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
#     x_1 \\
#     x_2
# \end{pmatrix} =
# \begin{pmatrix}
#     0 \\
#     0
# \end{pmatrix}
# $
#
#
# $
# \begin{pmatrix}
#     x_1 \\
#     x_2
# \end{pmatrix} =
# \alpha
# \begin{pmatrix}
#     1 \\
#     -3
# \end{pmatrix}, \Rightarrow \alpha = \frac{1}{\sqrt{1+3^2}}
# $
#
# Для $\lambda_2$:
#
# $
# \begin{pmatrix}
#     \frac{1}{2} & -\frac{3}{2} \\
#     -\frac{3}{2} & \frac{9}{2}
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
#     x_1 \\
#     x_2
# \end{pmatrix} =
# \begin{pmatrix}
#     0 \\
#     0
# \end{pmatrix}
# $
#
#
# $
# \begin{pmatrix}
#     x_1 \\
#     x_2
# \end{pmatrix} =
# \alpha
# \begin{pmatrix}
#     3 \\
#     1
# \end{pmatrix}, \Rightarrow \alpha = \frac{1}{\sqrt{1+3^2}}
# $

# %% [markdown]
# $
# Q = \frac{1}{\sqrt{10}}
# \begin{pmatrix}
#     1 & -3\\
#     3 & 1
# \end{pmatrix},
# Q^{\intercal} = \frac{1}{\sqrt{10}}
# \begin{pmatrix}
#     1 & 3\\
#     -3 & 1
# \end{pmatrix}
# $
#
# Проверим:
#
# $\Sigma_{id} = Q \cdot \Sigma \cdot Q^{\intercal} =
# \begin{pmatrix}
#     \frac{2}{15} & 0\\
#     0 & \frac{2}{15}
# \end{pmatrix} =
# \begin{pmatrix}
#     1/\lambda_1 & 0\\
#     0 & 1/\lambda_2
# \end{pmatrix}
# $

# %% [markdown]
# $p_{id}(x, y) = \frac{1}{2\pi \sqrt{\frac{4}{75}}}\cdot exp(-\frac{1}{2}(\frac{15}{2}x^2 + \frac{5}{2}y^2)) $

# %%
from math import pi, e, sqrt
import matplotlib.pyplot as plt

import numpy as np


os_x = np.arange(-5, 5, 0.3)
os_y = np.arange(-5, 5, 0.3)
x, y = np.meshgrid(os_x, os_y)
os_z = 5 * sqrt(3) / (4 * pi) * e ** (-0.5 * ( 7.5 * x ** 2 + 2.5 * y ** 2))
pic = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(x, y, os_z)
plt.show()

# %% [markdown]
# Задание 4.
#
# $\mathbb{E}(\xi, \eta)^{\top} = (-3, -1)^{\intercal}$.
#
# $\mathbb{E}(-\xi + \eta, -\xi + 3\eta)^{\intercal}$.
#
#
#
# $\mathbb{E}(-\xi + \eta, -\xi + 3\eta)^{\intercal} =
# \begin{pmatrix}
# \mathbb{E}(-\xi + \eta) \\
# \mathbb{E}(-\xi + 3\eta)
# \end{pmatrix} =
# \begin{pmatrix}
# -\mathbb{E}\xi + \mathbb{E}\eta \\
# -\mathbb{E}\xi + 3\mathbb{E}\eta
# \end{pmatrix}$
#
# $\mathbb{E}(-\xi + \eta, -\xi + 3\eta)^{\intercal} =
# \begin{pmatrix}
# 2 \\
# 0
# \end{pmatrix}$
#
# $\mathbb{E}(-\xi + \eta, -\xi + 3\eta)^{\intercal} =
# \begin{pmatrix}
# -1 & 1 \\
# -1 & 3
# \end{pmatrix} \cdot
# \begin{pmatrix}
# \xi \\
# \eta
# \end{pmatrix}$

# %% [markdown]
# $\Sigma' =
# \begin{pmatrix}
# -1 & 1\\
# -1 & 3
# \end{pmatrix} \cdot
# \frac{4}{75}
# \begin{pmatrix}
# 7 & \frac{3}{2}\\
# \frac{3}{2} & 3
# \end{pmatrix} \cdot
# \begin{pmatrix}
# -1 & -1\\
# 1 & 3
# \end{pmatrix} =
# \frac{4}{75}
# \begin{pmatrix}
# 7 & 10\\
# 10 & 25
# \end{pmatrix}
# $
#
# $\Sigma'^{-1} = \frac{1}{4}
# \begin{pmatrix}
# 25 & -10\\
# -10 & 7
# \end{pmatrix}
# $
#
# $det(\Sigma') = \frac{16}{75}$
#
# $\mathbb{D}(-\xi+\eta) = \frac{28}{75}, \mathbb{D}(-\xi + 3\eta) = \frac{4}{3}$
#
# $cov(-\xi + \eta, -\xi + 3\eta) = \frac{40}{75}$
#
# $\rho(-\xi + \eta, -\xi + 3\eta) = \frac{cov(-\xi + \eta, -\xi + 3\eta)}{\sqrt{\mathbb{D}(-\xi+\eta) \cdot \mathbb{D}(-\xi + 3\eta)}}  = \frac{2}{\sqrt{7}}$

# %% [markdown]
# $p'(x, y) = \frac{1}{2\pi \cdot \sqrt{\frac{16}{75}}} \cdot exp(-\frac{1}{2}(\frac{25}{4}(x-2)^2 - \frac{5}{2}(x-2)y + \frac{7}{4}y^2))$

# %%
from math import pi, e, sqrt
import matplotlib.pyplot as plt

import numpy as np


os_x = np.arange(-5, 5, 0.3)
os_y = np.arange(-5, 5, 0.3)
x, y = np.meshgrid(os_x, os_y)
os_z = 5 * sqrt(3) / (8 * pi) * e ** (-0.5 * ( 6.25 * (x - 2) ** 2 - 2.5 * (x - 2) * y + 1.75 * y ** 2))
pic = plt.figure()
ax = plt.axes(projection="3d")
ax.plot_wireframe(x, y, os_z)
plt.show()

# %% [markdown]
# Задание 5.

# %% [markdown]
# ## Выводы
#
# В ходе работы мы исследовали случайный вектор и его характеристики. Мы вычислили математические ожидания и ковариационную матрицу, что помогло понять, как связаны компоненты вектора. Также мы нашли аффинное и ортогональное преобразования
