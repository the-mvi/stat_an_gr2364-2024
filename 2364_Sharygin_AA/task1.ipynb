# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2364 Шарыгин Алексей Александрович. Вариант №19

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Нормальное распределение (одномерный случай):
#
# $ \xi \sim \mathcal{N}(a, \sigma^2) $
#
# $ p_\xi (x) = \cfrac{1}{\sigma\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{x-a}{\sigma}\right)^2\right) $
#
# Многомерное нормальное распределение:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ p_{\overrightarrow{\xi}} \left(\overrightarrow{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right) $
#
# Преобразование характеристик:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ \overrightarrow{\eta} = A \overrightarrow{\xi} + \overrightarrow{b} $
#
# $ \overrightarrow{\eta} \sim \mathcal{N}(A \overrightarrow{\mu} + \overrightarrow{b}, A \Sigma A^{\intercal}) $
#
# Условное распределение для абсолютно непрерывных величин:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} $
#
# Стандартное нормально распределение - нормальное распределение с нулевым мат. ожиданием и единичной дисперсией. В многомерном случае - нулевой вектор мат. ожидания и единичная ковариационная матрица.
#
# Аффинное преобразование - преобразование вида:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $
#
# ###

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Задача 1.
#
# **Плотность двумерного нормального распределения имеет вид:**
#
# $ p_{\xi, \eta}  (x, y) = C \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy+7y^2-9x-17y+13\right)\right) $
#
# **Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $ p_{\xi, \eta} $ .**
#
# Многомерное нормальное распределение:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ p_{\overrightarrow{\xi}} \left(\overrightarrow{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right) $
#
# Преобразуем исходное выражение и вычислим вектор математических ожиданий $ \overrightarrow{\mu} $ и ковариационную матрицу $ \Sigma $:
#
# $ p_{\xi, \eta}  (x, y) = C \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy+7y^2-9x-17y+13\right)\right) = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(x^2+xy+\cfrac{1}{4}y^2\right)+\cfrac{25}{4}y^2-9x-17y+13\right)\right) = $
#
# $ = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(x+\cfrac{1}{2}y\right)^2+\cfrac{25}{4}y^2-9x-17y+13\right)\right) = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(x+\cfrac{1}{2}y\right)^2+\cfrac{25}{4}y^2-9 \left(x+\cfrac{1}{2}y\right)-\cfrac{25}{2}y+13\right)\right) = $
#
# $ = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(\left(x+\cfrac{1}{2}y\right)^2-3 \left(x+\cfrac{1}{2}y\right)+\cfrac{9}{4}\right)+\cfrac{25}{4}y^2-\cfrac{25}{2}y+\cfrac{25}{4}\right)\right) = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(x+\cfrac{1}{2}y-\cfrac{3}{2}\right)^2+\cfrac{25}{4} \left(y-1\right)^2\right)\right) = $
#
# $ = C \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(\left(x-1\right)+\cfrac{1}{2}\left(y-1\right)\right)^2+\cfrac{25}{4} \left(y-1\right)^2\right)\right) = C \cdot \exp \left(-\cfrac{1}{2}\left(3\left(x-1\right)^2+3\left(x-1\right)\left(y-1\right)+7\left(y-1\right)^2\right)\right) $
#
# Представим в виде матричного умножения:
#
# $ p_{\xi, \eta}  (x, y) = C \cdot \exp \left(-\cfrac{1}{2}\left(x-1, y-1\right)\begin{pmatrix}
# 3 & \ 3/2\\
# 3/2 & 7
# \end{pmatrix}\begin{pmatrix}
# x-1\\
# y-1
# \end{pmatrix}\right) $
#
# Отсюда видно, что вектор математических ожиданий равен:
#
# $ \mathbb{E} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} = \overrightarrow{\mu} = \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix} $
#
# Обратная ковариационная матрица равна:
#
# $ \Sigma^{-1} = \begin{pmatrix}
# 3 & \ 3/2\\
# 3/2 & 7
# \end{pmatrix} $
#
# Обратим:
#
# $ \Sigma = \cfrac{4}{75}\begin{pmatrix}
# 7 & \ -3/2\\
# -3/2 & 3
# \end{pmatrix} $
#
# Найдём дисперсии компонент:
#
# $ \mathbb{D} \xi = \cfrac{28}{75} $
#
# $ \mathbb{D} \eta = \cfrac{12}{75} = \cfrac{4}{25} $
#
# Теперь найдём ковариацию и коэффициент корреляции:
#
# $ \mathrm{cov} (\xi, \eta) = -\cfrac{2}{25} $
#
# $ \rho (\xi, \eta) = \cfrac{\mathrm{cov} (\xi, \eta)}{\sqrt{\mathbb{D} \xi \cdot \mathbb{D} \eta}} = -\cfrac{2 \cdot 75}{4 \cdot 25\sqrt{21}} = -\cfrac{3}{2\sqrt{21}} \thickapprox -0.327 $
#
# Найдём константу $ C $:
#
# $ C = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} = \cfrac{5\sqrt{3}}{4\pi} $
#
# Итоговая функция распределения:
#
# $ p_{\xi, \eta}  (x, y) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy+7y^2-9x-17y+13\right)\right) $
#
# ###

# %% [markdown]
# ### Задача 1. Графики.

# %%
# Импортируем библиотеки и получим значения функции распределения
import numpy as np
import matplotlib.pyplot as plt

from math import pi, e, sqrt

x = np.arange(-1, 3, 0.1)
y = np.arange(-1, 3, 0.1)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 * sqrt(3) / (4 * pi) * e ** (-0.5 * (3 * xgrid ** 2 + 3 * xgrid * ygrid + 7 * ygrid ** 2 - 9 * xgrid - 17 * ygrid + 13))

# %%
# Выведем 3D график (каркасный)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %%
# Выведем 2D раскраску уровней
fig, ax = plt.subplots()
ax.set_xlabel("x")
ax.set_ylabel("y")
c = ax.contour(xgrid, ygrid, zgrid, 10)
c.clabel()
plt.show()

# %% [markdown]
# ### Задача 2.
#
# **Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.**
#
# Аффинное преобразование - преобразование вида:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $
#
# Стандартное нормально распределение - нормальное распределение с нулевым мат. ожиданием и единичной дисперсией. В многомерном случае - нулевой вектор мат. ожидания и единичная ковариационная матрица.
#
# Рассмотрим один из этапов преобразования выражения из первой задачи:
#
# $ p_{\xi, \eta}  (x, y) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy+7y^2-9x-17y+13\right)\right) = \cdots = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3 \left(x+\cfrac{1}{2}y-\cfrac{3}{2}\right)^2+\cfrac{25}{4} \left(y-1\right)^2\right)\right) $
#
# $ p_{\xi, \eta}  (x, y) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(\left(\sqrt{3}x+\cfrac{\sqrt{3}}{2}y-\cfrac{3\sqrt{3}}{2}\right)^2+\left(\cfrac{5}{2}y-\cfrac{5}{2}\right)^2\right)\right) $
#
# Используя коэффициенты, найдём стандартное нормальное распределение:
#
# $ \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = \begin{pmatrix}
# \sqrt{3} & \cfrac{\sqrt{3}}{2} \\
# 0 & \cfrac{5}{2}
# \end{pmatrix} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} + \begin{pmatrix}
# -\cfrac{3\sqrt{3}}{2} \\
# -\cfrac{5}{2}
# \end{pmatrix} = \begin{pmatrix}
# \sqrt{3}\xi+\cfrac{\sqrt{3}}{2}\eta-\cfrac{3\sqrt{3}}{2}\\
# \cfrac{5}{2}\eta-\cfrac{5}{2}
# \end{pmatrix} $
#
# Отсюда:
#
# $ A = \begin{pmatrix}
# \sqrt{3} & \cfrac{\sqrt{3}}{2} \\
# 0 & \cfrac{5}{2}
# \end{pmatrix} $
#
# $ \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} = \begin{pmatrix}
# -\cfrac{3\sqrt{3}}{2} \\
# -\cfrac{5}{2}
# \end{pmatrix} $
#
# Теперь убедимся, что это является стандартным нормальным распределением. Для этого найдём мат. ожидание и ковариационную матрицу:
#
# $ \mathbb{E} \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = \begin{pmatrix}
# \sqrt{3}+\cfrac{\sqrt{3}}{2}-\cfrac{3\sqrt{3}}{2}\\
# \cfrac{5}{2}-\cfrac{5}{2}
# \end{pmatrix} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# $ \mathrm{Var} \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# \sqrt{3} & \cfrac{\sqrt{3}}{2} \\
# 0 & \cfrac{5}{2}
# \end{pmatrix} \begin{pmatrix}
# 7 & \ -\cfrac{3}{2}\\
# -\cfrac{3}{2} & 3
# \end{pmatrix} \begin{pmatrix}
# \sqrt{3} & 0 \\
# \cfrac{\sqrt{3}}{2} & \cfrac{5}{2}
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# \cfrac{25\sqrt{3}}{4} & \ 0\\
# -\cfrac{15}{4} & \cfrac{15}{2}
# \end{pmatrix} \begin{pmatrix}
# \sqrt{3} & 0 \\
# \cfrac{\sqrt{3}}{2} & \cfrac{5}{2}
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# \cfrac{75}{4} & \ 0\\
# 0 & \cfrac{75}{4}
# \end{pmatrix} = \begin{pmatrix}
# 1 & \ 0\\
# 0 & 1
# \end{pmatrix} $
#
# ###

# %% [markdown]
# ### Задача 3.
#
# **Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.**
#
# Ортогональное преобразование - преобразование вида:
#
# $ \Sigma_{id} = Q \Sigma Q^{\intercal} $
#
# Для начала найдём собственные числа матрицы $ \Sigma^{-1} $, затем найдём собственные вектора и составим из них матрицу $ Q $:
#
# $ \det \left(\Sigma^{-1} - \lambda E\right) = 0 $
#
# $ \det \begin{pmatrix}
# 3 - \lambda & \ 3/2\\
# 3/2 & 7 - \lambda
# \end{pmatrix} = \left(3 - \lambda\right)\left(7 - \lambda\right) - \cfrac{9}{4} = \lambda^2 - 10\lambda + \cfrac{75}{4} = 0 $
#
# Отсюда собственные числа:
#
# $ \lambda_1 = \cfrac{15}{2}, \lambda_2 = \cfrac{5}{2} $
#
# Найдём собственные вектора:
#
# $ \lambda_1 = \cfrac{15}{2} \Rightarrow \begin{pmatrix}
# -9/2 & \ 3/2\\
# 3/2 & -1/2
# \end{pmatrix} \overrightarrow{v_1} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# $ \overrightarrow{v_1} = \alpha \begin{pmatrix}
# 1\\
# 3
# \end{pmatrix} $
#
# Нормируем:
#
# $ \alpha = \cfrac{1}{\sqrt{3^2 + 1 ^2}} = \cfrac{1}{\sqrt{10}} \Rightarrow \overrightarrow{v_1} = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 1\\
# 3
# \end{pmatrix} $
#
# Аналогично найдём второй вектор:
#
# $ \lambda_2 = \cfrac{5}{2} \Rightarrow \begin{pmatrix}
# 1/2 & \ 3/2\\
# 3/2 & 9/2
# \end{pmatrix} \overrightarrow{v_2} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# $ \overrightarrow{v_2} = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# -3\\
# 1
# \end{pmatrix} $
#
# Составим матрицу $ Q^{\intercal} $ и выполним преобразование:
#
# $ Q^{\intercal} = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 1 & -3\\
# 3 & 1
# \end{pmatrix} \Rightarrow Q = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 1 & 3\\
# -3 & 1
# \end{pmatrix} $
#
# $ \Sigma_{id} = Q \Sigma Q^{\intercal} = \cfrac{1}{\sqrt{10}} \cdot \cfrac{4}{75} \cdot \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 1 & 3\\
# -3 & 1
# \end{pmatrix} \begin{pmatrix}
# 7 & \ -3/2\\
# -3/2 & 3
# \end{pmatrix} \begin{pmatrix}
# 1 & -3\\
# 3 & 1
# \end{pmatrix} = \cfrac{4}{750} \begin{pmatrix}
# 5/2 & \ 15/2\\
# -45/2 & 15/2
# \end{pmatrix} \begin{pmatrix}
# 1 & -3\\
# 3 & 1
# \end{pmatrix} = \cfrac{4}{750} \begin{pmatrix}
# 25 & \ 0\\
# 0 & 75
# \end{pmatrix} = \begin{pmatrix}
# 2/15 & \ 0\\
# 0 & 2/5
# \end{pmatrix} $
#
# Заметим:
#
# $ \Sigma_{id} = \begin{pmatrix}
# 2/15 & \ 0\\
# 0 & 2/5
# \end{pmatrix} = \begin{pmatrix}
# 1/\lambda_1 & \ 0\\
# 0 & 1/\lambda_2
# \end{pmatrix} $
#
# Мат. ожидание:
#
# $ \mathbb{E} \begin{pmatrix}
# \xi_1\\
# \eta_1
# \end{pmatrix} = Q \cdot \overrightarrow{\mu} = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 1 & 3\\
# -3 & 1
# \end{pmatrix} \cdot \begin{pmatrix}
# 1\\
# 1
# \end{pmatrix} = \cfrac{1}{\sqrt{10}} \begin{pmatrix}
# 4\\
# -2
# \end{pmatrix} $
#
# $ \mathbb{D} \xi_1 = \cfrac{2}{15} $
#
# $ \mathbb{D} \eta_1 = \cfrac{2}{5} $
#
# $ \mathrm{cov} (\xi_1, \eta_1) = 0 $
#
# $ \rho (\xi_1, \eta_1) = 0 $
#
# Теперь найдём функцию плотности распределения:
#
# $ \Sigma_{id}^{-1} = \begin{pmatrix}
# 15/2 & 0\\
# 0 & 5/2
# \end{pmatrix} $
#
# $ p_{\xi_1, \eta_1}  (x, y) = \cfrac{1}{2\pi \sqrt{\cfrac{4}{75}}} \cdot \exp \left(-\cfrac{1}{2}\left(x - \cfrac{4}{\sqrt{10}}, y + \cfrac{2}{\sqrt{10}}\right)\begin{pmatrix}
# 15/2 & 0\\
# 0 & 5/2
# \end{pmatrix}\begin{pmatrix}
# x - \cfrac{4}{\sqrt{10}}\\
# y + \cfrac{2}{\sqrt{10}}
# \end{pmatrix}\right) = \cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{15}{2} \left(x - \cfrac{4}{\sqrt{10}}\right)^2 + \cfrac{5}{2} \left(y + \cfrac{2}{\sqrt{10}}\right)^2\right)\right) $
#
# ###

# %% [markdown]
# ### Задача 3. Графики.

# %%
# Получаем значения распределение. Библиотеки должны быть импортированы выше
x = np.arange(-0.7, 3.3, 0.1)
y = np.arange(-2.6, 1.4, 0.1)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 * sqrt(3) / (4 * pi) * e ** (-0.5 * (15 / 2 * (xgrid - 4 / sqrt(10)) ** 2 + 5 / 2 * (ygrid + 2 / sqrt(10)) ** 2))

# %%
# Выведем 3D график (каркасный)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %%
# Выведем 2D раскраску уровней
fig, ax = plt.subplots()
ax.set_xlabel("x")
ax.set_ylabel("y")
c = ax.contour(xgrid, ygrid, zgrid, 10)
c.clabel()
plt.show()

# %% [markdown]
# ### Задача 4.
#
# **Вычислить характеристики совместного распределения случайного вектора $ \left(3\xi+2\eta, 3\xi+\eta\right)^{\intercal} $ и записать его плотность. Построить график плотности полученного распределения.**
#
# Представим случайный вектор как преобразование вектора $ \left(\xi, \eta\right)^{\intercal} $:
#
# $ \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = B \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} + \begin{pmatrix}
# a\\
# b
# \end{pmatrix} $
#
# $ \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = \begin{pmatrix}
# 3 & 2\\
# 3 & 1
# \end{pmatrix} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} = \begin{pmatrix}
# 3\xi + 2\eta\\
# 3\xi + \eta
# \end{pmatrix} $
#
# Отсюда:
#
# $ B = \begin{pmatrix}
# 3 & 2\\
# 3 & 1
# \end{pmatrix} $
#
# $ \begin{pmatrix}
# a\\
# b
# \end{pmatrix} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}$
#
# Теперь найдём мат. ожидание и ковариационную матрицу по аналогии со второй задачей:
#
# $ \mathbb{E} \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = \begin{pmatrix}
# 5\\
# 4
# \end{pmatrix} $
#
# $ \Sigma_2 = \mathrm{Var} \begin{pmatrix}
# \xi_2\\
# \eta_2
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# 3 & 2\\
# 3 & 1
# \end{pmatrix} \begin{pmatrix}
# 7 & -3/2\\
# -3/2 & 3
# \end{pmatrix} \begin{pmatrix}
# 3 & 3\\
# 2 & 1
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# 18 & 3/2\\
# 39/2 & -3/2
# \end{pmatrix} \begin{pmatrix}
# 3 & 3\\
# 2 & 1
# \end{pmatrix} = \cfrac{4}{75} \begin{pmatrix}
# 57 & 111/2\\
# 111/2 & 57
# \end{pmatrix} = \cfrac{2}{25} \begin{pmatrix}
# 38 & 37\\
# 37 & 38
# \end{pmatrix} $
#
# Отсюда дисперсии компонент:
#
# $ \mathbb{D} \xi_2 = \cfrac{76}{25} $
#
# $ \mathbb{D} \eta_2 = \cfrac{76}{25} $
#
# Найдём ковариацию и коэффициент корреляции:
#
# $ \mathrm{cov} (\xi_2, \eta_2) = \cfrac{74}{25} $
#
# $ \rho (\xi_2, \eta_2) = \cfrac{\mathrm{cov} (\xi_2, \eta_2)}{\sqrt{\mathbb{D} \xi_2 \cdot \mathbb{D} \eta_2}} = \cfrac{74}{76} = \cfrac{37}{38} \thickapprox 0.974 $
#
# Найдём обратную матрицу и получим функцию распределения:
#
# $ \det \Sigma_2 = \cfrac{12}{25} $
#
# $ \Sigma_2^{-1} = \cfrac{1}{6} \begin{pmatrix}
# 38 & -37\\
# -37 & 38
# \end{pmatrix} $
#
# $ p_{\xi_2, \eta_2}  (x, y) = \cfrac{1}{2\pi \sqrt{\cfrac{12}{25}}} \cdot \exp \left(-\cfrac{1}{2} \cdot \cfrac{1}{6} \left(x-5, y-4\right)\begin{pmatrix}
# 38 & -37\\
# -37 & 38
# \end{pmatrix}\begin{pmatrix}
# x-5\\
# y-4
# \end{pmatrix}\right) = \cfrac{5}{4\pi \sqrt{3}} \cdot \exp \left(-\cfrac{1}{2} \left(\cfrac{19}{3}\left(x-5\right)^2-\cfrac{37}{3}\left(x-5\right)\left(y-4\right)+\cfrac{19}{3}\left(y-4\right)^2\right)\right) $
#
# ###

# %% [markdown]
# ### Задача 4. Графики.

# %%
# Получаем значения распределение. Библиотеки должны бить импортированы выше
x = np.arange(-5, 15, 0.25)
y = np.arange(-4, 14, 0.25)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = 5 / (4 * pi * sqrt(3)) * e ** (-0.5 * (19 / 3 * (xgrid - 5) ** 2 - 37 / 3 * (xgrid - 5) * (ygrid - 4) + 19 / 3 * (ygrid - 4) ** 2))

# %%
# Выведем 3D график (каркасный)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.plot_wireframe(xgrid, ygrid, zgrid)
plt.show()

# %%
# Выведем 2D раскраску уровней
fig, ax = plt.subplots()
ax.set_xlabel("x")
ax.set_ylabel("y")
c = ax.contour(xgrid, ygrid, zgrid, [0, 0.00001, 0.001, 0.02, 0.15])
c.clabel()
plt.show()

# %% [markdown]
# ### Задача 5.
#
# **Найти условное распределение $ \xi $ при условии $ \eta $. Вычислить $ \mathbb{E} \left(\xi|\eta\right) $ и $ \mathbb{D} \left(\xi|\eta\right) $.**
#
# Условное распределение:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} $
#
# Нормальное распределение (одномерный случай):
#
# $ \xi \sim \mathcal{N}(a, \sigma^2) $
#
# $ p_\xi (x) = \cfrac{1}{\sigma\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{x-a}{\sigma}\right)^2\right) $
#
# Зная характеристики случайного распределения $ \eta $ (из первой задачи), найдём функцию распределения:
#
# $ \mathbb{E} \eta = 1, \mathbb{D} \eta = \cfrac{4}{25} $
#
# $ p_\eta (y) = \cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{y-1}{2/5}\right)^2\right) = \cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{25}{4}y^2-\cfrac{25}{2}y+\cfrac{25}{4}\right)\right) $
#
# Подставим и преобразуем:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{\cfrac{5\sqrt{3}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy_0+7y_0^2-9x-17y_0+13\right)\right)}{\cfrac{5}{2\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{25}{4}y_0^2-\cfrac{25}{2}y_0+\cfrac{25}{4}\right)\right)} = \cfrac{2\sqrt{3}\sqrt{2\pi}}{4\pi} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3xy_0+\cfrac{3}{4}y_0^2-9x-\cfrac{9}{2}y_0+\cfrac{27}{4}\right)\right) = $
#
# $ = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(3x^2+3\left(y_0-3\right)x+\cfrac{3}{4}\left(y_0^2-6y_0+9\right)\right)\right) = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2} \cdot 3\left(x^2+\left(y_0-3\right)x+\cfrac{1}{4}\left(y_0-3\right)^2\right)\right) = $
#
# $ = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2} \cdot 3\left(x+\cfrac{y_0-3}{2}\right)^2\right) = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2} \left(\cfrac{x+\cfrac{y_0-3}{2}}{1/\sqrt{3}}\right)^2\right) $
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2} \cdot 3\left(x+\cfrac{y_0-3}{2}\right)^2\right) $
#
# Отсюда видно:
#
# $ \mathbb{E} \left(\xi|\eta\right) = -\cfrac{y_0-3}{2} $
#
# $ \mathbb{D} \left(\xi|\eta\right) = \cfrac{1}{3} $

# %% [markdown]
# ## Выводы
#
# В ходе данной работы были получены знания по работе с многомерными распределениями, а также получен опыт оформления отчётов в Jupyter Notebook.
