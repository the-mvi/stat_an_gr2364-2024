# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2364 Ротарь Владислав Владимирович. Вариант №13

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# $C=\frac{1}{\left(2\pi\right)^{n/2}\sqrt{\det\Sigma}}$, где n = 2
#
# $\Sigma = \Sigma^{-1}\cdot\frac{1}{det\Sigma^{-1}}$
#
# $\Sigma_{independent distribution}=Q\Sigma Q^T$
#
# Аффинное преобразование - преобразование вида:
# $\begin{pmatrix}
# x\\
# y
# \end{pmatrix}=A\begin{pmatrix}
# u\\
# v
# \end{pmatrix}+\begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix}$
#
# Условное распределение для абсолютно непрерывных величин:
# $p_{\xi|\eta=y_0}(x)=\frac{p_{\xi, \eta}(x, y_0)}{p_\eta(y_0)} $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.
#
# Плотность двумерного нормального распределения имеет вид: $$\rho_{\xi,\eta}(x,y)=C\cdot exp\left(-\frac{1}{2}\left( 2x^2-4xy+5y^2-4x-8y+14 \right)\right)$$

# %% [markdown]
# ## Выполнение работы
#
# Каждый пункт работы выполняется с помощью кода.

# %% [markdown]
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $\rho_{\xi, \eta}$

# %% [markdown]
# $2x^2-4xy+5y^2-4x-8y+14$
#
# $2x^2-4xy+2y^2-2y^2+5y^2-4x-8y+14$
#
# $2(x^2-2xy+y^2)+3y^2-4x-8y+14$
#
# $2(x^2-2xy+y^2)+3y^2-4x+4y-4y-8y+14$
#
# $2(x-y)^2+3y^2-4(x-y)-12y+14$
#
# $2((x-y)^2-2(x-y)+1-1)+3y^2-12y+14$
#
# $2((x-y)-1)^2+3y^2-12y+12$
#
# $2((x-y)-1)^2+3(y^2-4y+4-4)+12$
#
# $2((x-y)-1)^2+3(y-2)^2$
#
# $2(x-y-1+2-2)^2+3(y-2)^2$
#
# $2((x-3)-(y-2))^2+3(y-2)^2$
#
# $2((x-3)^2-2(x-3)(y-2)+(y-2)^2)+3(y-2)^2$
#
# $2(x-3)^2-4(x-3)(y-2)+5(y-2)^2$

# %% [markdown]
# Матрица ковариации будет выглядеть следующим образом:

# %% [markdown]
# \begin{equation*}
# \Sigma^{-1} = \left(
# \begin{array}{cccc}
# 2 & -2\\
# -2 & 5
# \end{array}
# \right)
# \end{equation*}

# %% [markdown]
# $det\Sigma^{-1}=2\cdot5-(-2)\cdot(-2)=10-4=6$

# %% [markdown]
# \begin{equation*}
# \Sigma = \left(
# \begin{array}{cccc}
# \frac{5}{6} & \frac{1}{3}\\
# \frac{1}{3} & \frac{1}{3}
# \end{array}
# \right)
# \end{equation*}

# %% [markdown]
# $\mathbb D_{\xi}=\frac{5}{6}$
#
# $\mathbb D_{\eta}=\frac{1}{3}$
#
# $cov(\xi, \eta)=\frac{1}{3}$
#
# $P_{\xi, \eta}=\frac{cov(\xi, \eta)}{\sqrt{\mathbb D_{\xi}\cdot\mathbb D_{\eta}}}=\frac{\sqrt{10}}{5}$

# %% [markdown]
# Найду вектор математических ожиданий. Для этого воспользуюсь формулой $A\mu=-0,5B$, где А $-$ матрица коэффициентов квадратичных членов уравнения, а B $-$ матрица коэффициентов линейных членов уравнения. Таким образом уравнение будет иметь вид:

# %% [markdown]
# \begin{array}{ccc}
# \begin{pmatrix}
# 2 & -2 \\
# -2 & 5
# \end{pmatrix}
# \mu
# =
# -\frac{1}{2}
# \begin{pmatrix}
# -4\\
# -8
# \end{pmatrix}
# \end{array}

# %% [markdown]
# \begin{array}{ccc}
# \begin{pmatrix}
# 2 & -2 \\
# -2 & 5
# \end{pmatrix}
# \mu
# =
# \begin{pmatrix}
# 2\\
# 4
# \end{pmatrix}
# \end{array}

# %% [markdown]
# $$\begin{equation*}
#  \begin{cases}
#    2\mu x-2\mu y = 2,
#    \\
#    -2\mu x+5 \mu y=4.
#  \end{cases}
# \end{equation*}$$
#
# $$\mu y=\mu x-1$$
# $$-2\mu x+5\mu y-5=4$$
# $$3\mu x=9$$
# $$\mu x=3 \\\  \mu y=2$$
# $$\mu=\begin{pmatrix}
# 3\\
# 2
# \end{pmatrix}$$

# %% [markdown]
# Как я потом выяснил, вектор мат ожидания можно было найти по уравнению $2(x-3)^2-4(x-3)(y-2)+5(y-2)^2$, откуда видны элементы 3,2 вектора мат ожидания.

# %% [markdown]
# Найду значение C:

# %% [markdown]
# $C=\frac{1}{(2\pi)^{\frac{n}{2}}\cdot \sqrt{det\Sigma}}=\frac{1}{2\pi\cdot \sqrt{\frac{1}{6}}}=\frac{\sqrt6}{2\pi}$

# %% [markdown]
# $$\rho_{\xi,\eta}(x,y)=\frac{\sqrt6}{2\pi}\cdot exp\left(-\frac{1}{2}\left( 2x^2-4xy+5y^2-4x-8y+14 \right)\right)$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from math import pi, e, sqrt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

x, y = np.meshgrid(np.linspace(-2, 7, 100), np.linspace(-2, 7, 100))
z = sqrt(6)/(2*pi)*e**(-0.5*(2*x**2 -4*x*y +5*y**2 -4*x -8*y +14))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 2. Найти афинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.

# %% [markdown]
# $2((x-y)-1)^2+3(y-2)=(\sqrt2 x-\sqrt2 y-\sqrt2)^2+(\sqrt3 y-2\sqrt3)^2$

# %% [markdown]
# \begin{array}{ccc}
# \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \sqrt2 \xi -\sqrt2 \eta-\sqrt2\\
# 0\xi +\sqrt3 \eta -2\sqrt3
# \end{pmatrix}
# \end{array}

# %% [markdown]
# \begin{array}{ccc}
# \begin{pmatrix}
# \sqrt2 & -\sqrt2\\
# 0 & \sqrt3
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# \frac{5}{6} & \frac{1}{3}\\
# \frac{1}{3} & \frac{1}{3}
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# \sqrt2 & 0\\
# -\sqrt2 & \sqrt3
# \end{pmatrix}
# =
# \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix}
# \end{array}

# %% [markdown]
# \begin{array}{ccc}
# \begin{pmatrix}
# \sqrt2 & -\sqrt2\\
# 0 & \sqrt3
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# 3\\
# 2
# \end{pmatrix}
# +
# \begin{pmatrix}
# -\sqrt2\\
# -2\sqrt3
# \end{pmatrix}
# =
# \begin{pmatrix}
# 0 \\
# 0
# \end{pmatrix}
# \end{array}

# %% [markdown]
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности случайного распределения.

# %% [markdown]
# Вектор мат ожидания: $\mathbb E(\xi, \eta)=\begin{pmatrix}
# 3\\
# 2
# \end{pmatrix}$

# %% [markdown]
# $det (\Sigma^{-1}-\lambda E)=0 \Rightarrow det
# \begin{pmatrix}
# 2-\lambda & -2\\
# -2 & 5-\lambda
# \end{pmatrix}=0
# \Rightarrow (2-\lambda)(5-\lambda)-(-2)(-2)=0
# \Rightarrow \lambda^2-7\lambda+6=0
# \Rightarrow \lambda_{1,2} =1;6$

# %% [markdown]
# Для $\lambda_1=1$:

# %% [markdown]
# $\begin{pmatrix}
# 2-1 & -2\\
# -2 & 5-1
# \end{pmatrix}=
# \begin{pmatrix}
# 1 & -2\\
# -2 & 4
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}
# =0
# $

# %% [markdown]
# $\begin{cases}
#    x_1 -2x_2=0,
#    \\
#    -2x_1 +4x_2 =0.
#  \end{cases}
# \Rightarrow
# x_1=2x_2
# $

# %% [markdown]
# $
# \begin{pmatrix}
# 1 & -2\\
# -2 & 4
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# 2\\
# 1
# \end{pmatrix}
# =
# \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}
# $

# %% [markdown]
# $\vec U_1=\lambda
# \begin{pmatrix}
# 2\\
# 1
# \end{pmatrix}
# =\frac{1}{\sqrt{1^2+2^2}}
# =\frac{1}{\sqrt5}
# \begin{pmatrix}
# 2\\
# 1
# \end{pmatrix}$

# %% [markdown]
# Для $\lambda_2=6$:

# %% [markdown]
# $\begin{pmatrix}
# 2-6 & -2\\
# -2 & 5-6
# \end{pmatrix}=
# \begin{pmatrix}
# -4 & -2\\
# -2 & -1
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# x_1\\
# x_2
# \end{pmatrix}
# =0
# $

# %% [markdown]
# $\begin{cases}
#    -4x_1 -2x_2 =0,
#    \\
#    -2x_1-x_2 =0.
#  \end{cases}
# \Rightarrow
# x_2=-2x_1
# $

# %% [markdown]
# $
# \begin{pmatrix}
# -4 & -2\\
# -2 & -1
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# 1\\
# -2
# \end{pmatrix}
# =
# \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}
# $

# %% [markdown]
# $\vec U_2=\lambda
# \begin{pmatrix}
# 1\\
# -2
# \end{pmatrix}
# =\frac{1}{\sqrt{1^2+(-2)^2}}
# =\frac{1}{\sqrt5}
# \begin{pmatrix}
# 1\\
# -2
# \end{pmatrix}$

# %% [markdown]
# $Q^T=\frac{1}{\sqrt5}
# \begin{pmatrix}
# 2 & 1\\
# 1 & -2
# \end{pmatrix}\Rightarrow
# Q=\frac{1}{\sqrt5}
# \begin{pmatrix}
# 2 & 1\\
# 1 & -2
# \end{pmatrix}
# $

# %% [markdown]
# $\Sigma_{independent distribution}=Q\Sigma Q^T=
# \frac{1}{\sqrt5}
# \begin{pmatrix}
# 2 & 1\\
# 1 & -2
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# \frac{5}{6} & \frac{1}{3}\\
# \frac{1}{3} & \frac{1}{3}
# \end{pmatrix}
# \cdot
# \frac{1}{\sqrt5}
# \begin{pmatrix}
# 2 & 1\\
# 1 & -2
# \end{pmatrix}
# =\begin{pmatrix}
# 1 & 0\\
# 0 & \frac{1}{6}
# \end{pmatrix}
# $

# %% [markdown]
# $\Sigma_{independent distribution}^{-1}=
# \begin{pmatrix}
# 1 & 0\\
# 0 & 6
# \end{pmatrix}
# $

# %% [markdown]
# $\mu_{id} = Q\cdot \vec\mu=
# \begin{pmatrix}
# \frac{8\sqrt{5}}{5}\\
# -\frac{\sqrt{5}}{5}
# \end{pmatrix}$

# %% [markdown]
# $\rho_{\xi st,\eta st}(x,y)=\frac{\sqrt{6}}{2\pi}\cdot exp\left(-\frac{1}{2}\left( x^2 -\frac{16\sqrt{5}x}{5} +6y^2 + \frac{12\sqrt{5}y}{5}+14\right)\right)$

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

x, y = np.meshgrid(np.linspace(-7, 7, 1000), np.linspace(-7, 7, 1000))
z = (sqrt(6)/(2*pi))*e**(-0.5*(x**2 -(16*sqrt(5)*x)/5 +6*y**2+(12*sqrt(5)*y)/5 +14))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 4. Вычислить характеристики совместного распределения случайного вектора $(4\xi -\eta, -3\xi +3\eta)^T$ и записать его плотность. Построить график полученного распределения.

# %% [markdown]
# $\text {Мат ожидание заданного вектора:}\begin{pmatrix}
# 4 & -1\\
# -3 & 3
# \end{pmatrix}\cdot
# \begin{pmatrix}
# 3\\
# 2
# \end{pmatrix}=
# \begin{pmatrix}
# 10\\
# -3
# \end{pmatrix}$

# %% [markdown]
# $\text {Матрица ковариации:}
# \begin{pmatrix}
# 4 & -1\\
# -3 & 3
# \end{pmatrix}\cdot
# \begin{pmatrix}
# \frac{5}{6} & \frac{1}{3}\\
# \frac{1}{3} & \frac{1}{3}
# \end{pmatrix}\cdot
# \begin{pmatrix}
# 4 & -3\\
# -1 & 3
# \end{pmatrix}=
# \begin{pmatrix}
# 11 & -6\\
# -6 & \frac{9}{2}
# \end{pmatrix}
# $
#
#
# Определитель равен $\frac{27}{2}$

# %% [markdown]
# $\mathbb D \xi=11$

# %% [markdown]
# $\mathbb D \eta=\frac{9}{2}$

# %% [markdown]
# $cov(\xi, \eta)=-6$

# %% [markdown]
# $P_{\xi, \eta}=\frac{cov(\xi, \eta)}{\sqrt{\mathbb D_{\xi}\cdot\mathbb D_{\eta}}}=\frac{2\sqrt{22}}{11}\approx-0,85$

# %% [markdown]
# Обратная матрица ковариации: $
# \begin{pmatrix}
# \frac{1}{3} & \frac{4}{9}\\
# \frac{4}{9} & \frac{22}{27}
# \end{pmatrix}$

# %% [markdown]
# $\rho_{\xi st,\eta st}(x,y)=\frac{1}{2\pi\sqrt{\frac{27}{2}}}\cdot exp\left(-\frac{1}{2}\left( \frac{1}{3}(x-10)^2 +\frac{2}{9}(x-10)(y+3)+\frac{22}{27}(y+3)^2 \right)\right)$

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

x, y = np.meshgrid(np.linspace(0, 20, 100), np.linspace(-20, 15, 100))
z = (1/(2*pi*sqrt(27/2)))*e**(-0.5*(1/3*(x-10)**2 +8/9*(x-10)*(y+3) +22/27*(y+3)**2))

ax.plot_surface(x, y, z)

plt.show()

# %% [markdown]
# 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $\mathbb E(\xi|\eta)$ и $\mathbb D(\xi|\eta)$

# %% [markdown]
# $ p_{\xi|\eta=y_0}(x)=\frac{p_{\xi,\eta}(x, y)}{p_\eta(y)} $

# %% [markdown]
# $\rho_\eta(y_0)=\frac{1}{\sqrt{2\pi\sigma^2}}\cdot \exp \left(-\frac{1}{2}\left(\frac{(y_0-\mu)^2}{\sigma^2}\right)\right)$

# %% [markdown]
# Где $\mu -$ мат ожидание, равное 2, а $\sigma^2 -$ дисперсия, равная $\frac{1}{3}$

# %% [markdown]
# $\rho_\eta(y)=\frac{1}{\sqrt{2\pi\frac{1}{3}}}\cdot \exp \left(-\frac{1}{2}\left(\frac{(y_0-2)^2}{\frac{1}{3}}\right)\right)=
# \frac{1}{\sqrt{2\pi\frac{1}{3}}}\cdot \exp \left(-\frac{1}{2}(3y_0^2-12y_0+12)\right)
# $

# %% [markdown]
# $\frac{\frac{\sqrt6}{2\pi}\cdot exp\left(-\frac{1}{2}\left( 2x^2-4xy_0+5y_0^2-4x-8y_0+14 \right)\right)}
# {\frac{1}{\sqrt{2\pi\frac{1}{3}}}\cdot \exp \left(-\frac{1}{2}(3y_0^2-12y_0+12)\right)}=
# \frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}(2x^2-4xy_0+2y_0^2-4x+4y_0+2)\right)$

# %% [markdown]
# $\frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}(2x^2-4xy_0+2y_0^2-4x+4y_0+2)\right)=
# \frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}\cdot 2(x^2-2xy_0+y_0^2-2x+2y_0+1)\right)=
# \frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}\cdot 2(x^2+(y_0+1)^2-2x(y_0+1))\right)=
# $

# %% [markdown]
# $=\frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}\cdot 2(x-(y_0+1)^2)\right)=
# \frac{\sqrt\pi}{\pi}\cdot \exp \left(-\frac{1}{2}\cdot \left(\frac{(x-(y_0+1))^2}{\frac{1}{2}}\right)\right)
# $

# %% [markdown]
# Таким образом, $\mathbb E_{(\xi | \eta)}=y_0+1$
#
# $\mathbb D_{(\xi | \eta)}=\frac{1}{2}$

# %% [markdown]
# ## Вывод
#
# В ходе выполнения практической работы были исследованы свойства двумерного случайного вектора, обладающего нормальным распределением. Были рассмотрены основные характеристики такого вектора, включая матрицу ковариаций и средние значения. Были получены знания, позволяющие преобразовывать случайный вектор из общего нормального распределения в стандартное нормальное распределение, что позволяет упростить анализ и расчет вероятностных характеристик.
#
# Также были освоены методы декорреляции вектора, позволяющие преобразовать его в вектор с независимыми компонентами.
#
# Помимио этого были получены базовые знания работы Jupiter Notebook.
